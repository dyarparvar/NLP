# %% [markdown]
# <a href="https://colab.research.google.com/github/dyarparvar/NLP/blob/main/Sentiment_Analysis_of_Movie_Reviews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sentiment analysis of movie reviews
#
# ## Scenario
# As part of a market research exercise for a film studio planning a new science-fiction film, you have been tasked with a data science project to research customer feedback on films in a related genre. One question you will be asked to investigate is whether there’s a relationship between the proportion of feedback that is positive and production budgets. Before you compare sentiment scores between films, however, you need to construct a viable preprocessing pipeline and train a model.

# %% [markdown]
# ## ✅ 0-2. Setup & Data

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2025.11.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
# !pip install beautifulsoup4
# Out:
# ERROR: Operation cancelled by user
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3343529003.py in <cell line: 0>()
# ----> 1 get_ipython().system('pip install beautifulsoup4')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#     150
#     151     if pip_warn:
# --> 152       _pip.print_previous_import_warning(output)
#     153
#     154   def _send_error(self, exc_content):
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_pip.py in print_previous_import_warning(output)
#      54 def print_previous_import_warning(output):
#      55   """Prints a warning about previously imported packages."""
# ---> 56   packages = _previously_imported_packages(output)
#      57   if packages:
#      58     # display a list of packages using the colab-display-data mimetype, which
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_pip.py in _previously_imported_packages(pip_output)
#      48 def _previously_imported_packages(pip_output):
#      49   """List all previously imported packages from a pip install."""
# ---> 50   installed = set(_extract_toplevel_packages(pip_output))
#      51   return sorted(installed.intersection(set(sys.modules)))
#      52
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_pip.py in _extract_toplevel_packages(pip_output)
#      37   """Extract the list of toplevel packages associated with a pip install."""
#      38   toplevel = collections.defaultdict(set)
# ---> 39   for m, ps in importlib.metadata.packages_distributions().items():
#      40     for p in ps:
#      41       toplevel[p].add(m)
#
# /usr/lib/python3.12/importlib/metadata/__init__.py in packages_distributions()
#     946     for dist in distributions():
#     947         for pkg in _top_level_declared(dist) or _top_level_inferred(dist):
# --> 948             pkg_to_dist[pkg].append(dist.metadata['Name'])
#     949     return dict(pkg_to_dist)
#     950
#
# /usr/local/lib/python3.12/dist-packages/importlib_metadata/__init__.py in metadata(self)
#     525
#     526         text = (
# --> 527             self.read_text('METADATA')
#     528             or self.read_text('PKG-INFO')
#     529             # This last clause is here to support old egg-info files.  Its
#
# /usr/local/lib/python3.12/dist-packages/importlib_metadata/__init__.py in read_text(self, filename)
#     996             PermissionError,
#     997         ):
# --> 998             return self._path.joinpath(filename).read_text(encoding='utf-8')
#     999
#    1000         return None
#
# /usr/lib/python3.12/pathlib.py in read_text(self, encoding, errors)
#    1026         encoding = io.text_encoding(encoding)
#    1027         with self.open(mode='r', encoding=encoding, errors=errors) as f:
# -> 1028             return f.read()
#    1029
#    1030     def write_bytes(self, data):
#
# /usr/lib/python3.12/codecs.py in decode(self, input, final)
#
# KeyboardInterrupt:

# %%
# For GloVe via spaCy
# !pip install spacy
# !python -m spacy download en_core_web_lg

# %%
# For Word2Vec
# !pip install gensim
from gensim.models import Word2Vec

# %%
# For NLTK
# !pip install nltk
# !pip install svgling
import nltk
nltk.download("all")

# %%
import pandas as pd
import numpy as np

from scipy.spatial.distance import cosine

from datasets import load_dataset

import spacy

import string
import re

from bs4 import BeautifulSoup # remove HTML tags



from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer

from sklearn.feature_extraction.text import CountVectorizer  # BoW
from sklearn.feature_extraction.text import TfidfVectorizer  # Tf-idf


from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report

# %%
dataset = load_dataset("stanfordNLP/sst2")

# %%
dataset

# %% [markdown]
# ## ✅ 3. Train & Validation split

# %%
train_data = dataset["train"]
train_data = train_data.to_pandas()
train_data
# Out:
#          idx                                           sentence  label
# 0          0       hide new secretions from the parental units       0
# 1          1               contains no wit , only labored gags       0
# 2          2  that loves its characters and communicates som...      1
# 3          3  remains utterly satisfied to remain the same t...      0
# 4          4  on the worst revenge-of-the-nerds clichés the ...      0
# ...      ...                                                ...    ...
# 67344  67344                               a delightful comedy       1
# 67345  67345                   anguish , anger and frustration       0
# 67346  67346  at achieving the modest , crowd-pleasing goals...      1
# 67347  67347                                  a patient viewer       1
# 67348  67348  this new jangle of noise , mayhem and stupidit...      0
#
# [67349 rows x 3 columns]

# %%
train_sentence = train_data["sentence"]
train_label = train_data["label"]

# %%
val_data = dataset["validation"]
val_data = val_data.to_pandas()
val_data
# Out:
#      idx                                           sentence  label
# 0      0    it 's a charming and often affecting journey .       1
# 1      1                 unflinchingly bleak and desperate       0
# 2      2  allows us to hope that nolan is poised to emba...      1
# 3      3  the acting , costumes , music , cinematography...      1
# 4      4                  it 's slow -- very , very slow .       0
# ..   ...                                                ...    ...
# 867  867              has all the depth of a wading pool .       0
# 868  868              a movie with a real anarchic flair .       1
# 869  869  a subject like this should inspire reaction in...      0
# 870  870  ... is an arthritic attempt at directing by ca...      0
# 871  871  looking aristocratic , luminous yet careworn i...      1
#
# [872 rows x 3 columns]

# %%
val_sentence = val_data["sentence"]
val_label = val_data["label"]

# %%
test_data = dataset["test"]
test_data = test_data.to_pandas()
test_data
# Out:
#        idx                                           sentence  label
# 0        0             uneasy mishmash of styles and genres .     -1
# 1        1  this film 's relationship to actual tension is...     -1
# 2        2  by the end of no such thing the audience , lik...     -1
# 3        3  director rob marshall went out gunning to make...     -1
# 4        4  lathan and diggs have considerable personal ch...     -1
# ...    ...                                                ...    ...
# 1816  1816  it risks seeming slow and pretentious , becaus...     -1
# 1817  1817  take care of my cat offers a refreshingly diff...     -1
# 1818  1818  davis has filled out his cast with appealing f...     -1
# 1819  1819  it represents better-than-average movie-making...     -1
# 1820  1820  dazzling and sugar-sweet , a blast of shallow ...     -1
#
# [1821 rows x 3 columns]

# %%
test_sentence = test_data["sentence"]
test_label = test_data["label"]

# %%
# Check labels
print(f"Unique train labels: {np.unique(train_label)}")
print(f"Unique validation labels: {np.unique(val_label)}")
print(f"Unique test labels: {np.unique(test_label)}")
# Out:
# Unique train labels: [0 1]
# Unique validation labels: [0 1]
# Unique test labels: [-1]

# %% [markdown]
# *SST2's test set is designed for competition submission and therefore it has placeholder labels (-1) instead of real labels. Therefore we will use the validation set as the test set.*

# %% [markdown]
# ## ✅ 4-7. Similarity
#
# 4. Calculate the cosine similarity of the 5th and 100th sentence within the train split.
# 5. Calculate the cosine similarity of the 5th and 15,000th sentence within the train split.
# 6. Calculate the cosine similarity of the 5th and 50,000th sentence within the train split.
# 7. Comment on the cosine similarity scores.

# %% [markdown]
# ### **✅ GloVe via spaCy**
#
# (pre-trained)
#
# *Semantic Similarity*

# %%
# Load the model
nlp = spacy.load("en_core_web_lg")

# %% [markdown]
# Converting each sentence to an nlp object using spaCy

# %%
# Function to convert sentence to nlp object using spaCy
def sentence_to_nlp_spacy_glove(sentence, nlp_model):
    doc = nlp_model(sentence)
    # return the averaged word vectors
    return doc

# %%
# Convert each sentence to nlp object
nlp_5_glove = sentence_to_nlp_spacy_glove(train_sentence[4], nlp)
nlp_100_glove = sentence_to_nlp_spacy_glove(train_sentence[99], nlp)
nlpc_15000_glove = sentence_to_nlp_spacy_glove(train_sentence[14999], nlp)
nlp_50000_glove = sentence_to_nlp_spacy_glove(train_sentence[49999], nlp)

# Calculate semantic similarity
sim_5_100_glove = nlp_5_glove.similarity(nlp_100_glove)
sim_5_15000_glove = nlp_5_glove.similarity(nlpc_15000_glove)
sim_5_50000_glove = nlp_5_glove.similarity(nlp_50000_glove)

# %%
print(f"{train_sentence[4]} \n {sim_5_100_glove} \n {train_sentence[99]}")
# Out:
# on the worst revenge-of-the-nerds clichés the filmmakers could dredge up
#  0.7925307154655457
#  acted and directed , it 's clear that washington most certainly has a new career ahead of him

# %%
print(f"{train_sentence[4]} \n {sim_5_15000_glove} \n {train_sentence[14999]}")
# Out:
# on the worst revenge-of-the-nerds clichés the filmmakers could dredge up
#  0.2320917546749115
#  eloquent

# %%
print(f"{train_sentence[4]} \n {sim_5_50000_glove} \n {train_sentence[49999]}")
# Out:
# on the worst revenge-of-the-nerds clichés the filmmakers could dredge up
#  0.23432505130767822
#  stylish

# %% [markdown]
# **Alternative Approach**

# %% [markdown]
# Converting each sentence to a vector using spaCy

# %%
# Convert each sentence to vector
vec_5_glove = nlp_5_glove.vector
vec_100_glove = nlp_100_glove.vector
vec_15000_glove = nlpc_15000_glove.vector
vec_50000_glove = nlp_50000_glove.vector

# %%
# Function to calculate cosine similarities
def cosine_similarity(vec1, vec2):
  if (np.linalg.norm(vec1) == 0) | (np.linalg.norm(vec2) == 0):
      return 0
  else:
      return 1 - cosine(vec1, vec2)

# %%
# Calculate semantic similarity
sim_5_100_glove = cosine_similarity(vec_5_glove, vec_100_glove)
sim_5_15000_glove = cosine_similarity(vec_5_glove, vec_15000_glove)
sim_5_50000_glove = cosine_similarity(vec_5_glove, vec_50000_glove)

# %%
print(f"{train_sentence[4]} \n {sim_5_100_glove} \n {train_sentence[99]}")
# Out:
# on the worst revenge-of-the-nerds clichés the filmmakers could dredge up
#  0.7925306558609009
#  acted and directed , it 's clear that washington most certainly has a new career ahead of him

# %%
print(f"{train_sentence[4]} \n {sim_5_15000_glove} \n {train_sentence[14999]}")
# Out:
# on the worst revenge-of-the-nerds clichés the filmmakers could dredge up
#  0.2320917248725891
#  eloquent

# %%
print(f"{train_sentence[4]} \n {sim_5_50000_glove} \n {train_sentence[49999]}")
# Out:
# on the worst revenge-of-the-nerds clichés the filmmakers could dredge up
#  0.23432505130767822
#  stylish

# %% [markdown]
# ### **✅ Word2Vec**
#
# (trained on our data)
#
# *Semantic Similarity*

# %%
# Tokenise and train on the data
train_tokens_w2v = [word_tokenize(sentence.lower()) for sentence in train_sentence]

w2v = Word2Vec(train_tokens_w2v,
               vector_size=100,
               window=5,
               min_count=2)

# %%
train_tokens_w2v[4]
# Out:
# ['on',
#  'the',
#  'worst',
#  'revenge-of-the-nerds',
#  'clichés',
#  'the',
#  'filmmakers',
#  'could',
#  'dredge',
#  'up']

# %%
# Define the function
def get_sentence_vector_w2v(sentence, model):
    tokens = word_tokenize(sentence.lower())

    vectors = [model.wv[token] for token in tokens]

    if len(vectors) == 0:
        return np.zeros(model.vector_size)

    return np.mean(vectors, axis=0)

# %%
# Calculate similarity
sim_5_100_w2v = cosine_similarity(get_sentence_vector_w2v(train_sentence[4], w2v),
                           get_sentence_vector_w2v(train_sentence[99], w2v))
sim_5_15000_w2v = cosine_similarity(get_sentence_vector_w2v(train_sentence[4], w2v),
                             get_sentence_vector_w2v(train_sentence[14999], w2v))
sim_5_50000_w2v = cosine_similarity(get_sentence_vector_w2v(train_sentence[4], w2v),
                             get_sentence_vector_w2v(train_sentence[49999], w2v))

# %%
print(f"{train_sentence[4]} \n {sim_5_100_w2v} \n {train_sentence[99]}")
# Out:
# on the worst revenge-of-the-nerds clichés the filmmakers could dredge up
#  0.6973946690559387
#  acted and directed , it 's clear that washington most certainly has a new career ahead of him

# %%
print(f"{train_sentence[4]} \n {sim_5_15000_w2v} \n {train_sentence[14999]}")
# Out:
# on the worst revenge-of-the-nerds clichés the filmmakers could dredge up
#  0.4082188606262207
#  eloquent

# %%
print(f"{train_sentence[4]} \n {sim_5_50000_w2v} \n {train_sentence[49999]}")
# Out:
# on the worst revenge-of-the-nerds clichés the filmmakers could dredge up
#  0.40622401237487793
#  stylish

# %% [markdown]
# ## ✅ 8. Preprocessing
#
# perform several processing steps as described below to the train and validation texts

# %% [markdown]
# - Remove any punctuation and html tags.

# %%
# Function to remove punctuation
def remove_punctuation(text):
    # Make a translation table for str.translate() that maps each punctuation character to none.
    translator = str.maketrans("", "", string.punctuation)
    # Translate the text using the translation table.
    return text.translate(translator)

# %%
# Uses BeautifulSoup for HTML cleaning
processed_train_sentence = [BeautifulSoup(sentence, "html.parser").get_text() for sentence in train_sentence]
processed_val_sentence = [BeautifulSoup(sentence, "html.parser").get_text() for sentence in val_sentence]

# Uses a regular expression to remove most standard punctuation
processed_train_sentence = [remove_punctuation(sentence) for sentence in processed_train_sentence]
processed_val_sentence = [remove_punctuation(sentence) for sentence in processed_val_sentence]

# Convert to lowercase to maintain consistency
processed_train_sentence = [sentence.lower() for sentence in processed_train_sentence]
processed_val_sentence = [sentence.lower() for sentence in processed_val_sentence]

# %%
train_sentence[8]
# Out:
# "a depressed fifteen-year-old 's suicidal poetry "

# %%
processed_train_sentence[8]
# Out:
# 'a depressed fifteenyearold s suicidal poetry '

# %% [markdown]
# ### ✅ NLTK

# %% [markdown]
#  - Tokenize the text into tokens.

# %%
train_tokens = [word_tokenize(sentence) for sentence in processed_train_sentence]
val_tokens = [word_tokenize(sentence) for sentence in processed_val_sentence]
# test_tokens = [word_tokenize(sentence) for sentence in processed_test_sentence]

# %%
train_tokens[8]
# Out:
# ['a', 'depressed', 'fifteenyearold', 's', 'suicidal', 'poetry']

# %% [markdown]
#  - Remove stop words from your text.

# %%
# Stopwords
stop_words = set(stopwords.words("english"))

# Filter stopwords while keeping sentence structure
# without flattening the tokens all into one single list
filtered_train_tokens = [[token for token in sentence if token not in stop_words]
                         for sentence in train_tokens]
filtered_val_tokens = [[token for token in sentence if token not in stop_words]
                       for sentence in val_tokens]

# %%
filtered_train_tokens[8]
# Out:
# ['depressed', 'fifteenyearold', 'suicidal', 'poetry']

# %% [markdown]
#  - Perform lemmatisation and stemming on your text (one at a time).

# %%
# Initialise lemmatiser
wnl = WordNetLemmatizer()

# %%
lemma_train = [" ".join([wnl.lemmatize(token, pos="v") for token in sentence])
                      for sentence in filtered_train_tokens]
lemma_val = [" ".join([wnl.lemmatize(token, pos="v")  for token in sentence])
                    for sentence in filtered_val_tokens]

# %%
lemma_train[3]
# Out:
# 'remain utterly satisfy remain throughout'

# %%
# Initialise the stemmer
stemmer = PorterStemmer()

# %%
stem_train = [" ".join([stemmer.stem(token) for token in sentence])
                     for sentence in filtered_train_tokens]
stem_val = [" ".join([stemmer.stem(token) for token in sentence])
                     for sentence in filtered_val_tokens]

# %%
stem_train[3]
# Out:
# 'remain utterli satisfi remain throughout'

# %%
train_data["lemma_sentence"] = lemma_train

# %%
val_data["lemma_sentence"] = lemma_val

# %%
train_data["stem_sentence"] = stem_train

# %%
val_data["stem_sentence"] = stem_val

# %%
train_data.head()
# Out:
#    idx                                           sentence  label  \
# 0    0       hide new secretions from the parental units       0
# 1    1               contains no wit , only labored gags       0
# 2    2  that loves its characters and communicates som...      1
# 3    3  remains utterly satisfied to remain the same t...      0
# 4    4  on the worst revenge-of-the-nerds clichés the ...      0
#
#                                       lemma_sentence  \
# 0                 hide new secretions parental units
# 1                              contain wit labor gag
# 2  love character communicate something rather be...
# 3           remain utterly satisfy remain throughout
# 4  worst revengeofthenerds clichés filmmakers cou...
#
#                                        stem_sentence
# 0                        hide new secret parent unit
# 1                              contain wit labor gag
# 2  love charact commun someth rather beauti human...
# 3           remain utterli satisfi remain throughout
# 4  worst revengeofthenerd cliché filmmak could dredg

# %%
val_data.head()
# Out:
#    idx                                           sentence  label  \
# 0    0    it 's a charming and often affecting journey .       1
# 1    1                 unflinchingly bleak and desperate       0
# 2    2  allows us to hope that nolan is poised to emba...      1
# 3    3  the acting , costumes , music , cinematography...      1
# 4    4                  it 's slow -- very , very slow .       0
#
#                                       lemma_sentence  \
# 0                         charm often affect journey
# 1                      unflinchingly bleak desperate
# 2  allow us hope nolan poise embark major career ...
# 3  act costume music cinematography sound astound...
# 4                                          slow slow
#
#                                        stem_sentence
# 0                         charm often affect journey
# 1                         unflinchingli bleak desper
# 2  allow us hope nolan pois embark major career c...
# 3  act costum music cinematographi sound astound ...
# 4                                          slow slow

# %% [markdown]
# ## ✅ 9. BoW & Similarity
# *Statistical Similarity*

# %%
# Create vectorizer
count_vectorizer = CountVectorizer(analyzer = "word",
                                   lowercase=True,
                                   stop_words="english",
                                   max_features=3000)

# %% [markdown]
# **lemmatised sentences**

# %%
# Calculate BoW - lemmatised sentences
train_bow_lemma = count_vectorizer.fit_transform(lemma_train) # Learn vocabulary from training
val_bow_lemma = count_vectorizer.transform(lemma_val) # Apply to validation

# %%
# Get vocabulary and tokens after fitting
vocabulary_bow = count_vectorizer.vocabulary_
tokens_bow = count_vectorizer.get_feature_names_out()

# %%
vocabulary_bow
# Out:
# {'hide': np.int64(1230),
#  'new': np.int64(1753),
#  'contain': np.int64(530),
#  'wit': np.int64(2954),
#  'labor': np.int64(1487),
#  'gag': np.int64(1089),
#  'love': np.int64(1572),
#  'character': np.int64(379),
#  'communicate': np.int64(482),
#  'beautiful': np.int64(217),
#  'human': np.int64(1283),
#  'nature': np.int64(1743),
#  'remain': np.int64(2151),
#  'utterly': np.int64(2846),
#  'satisfy': np.int64(2255),
#  'worst': np.int64(2976),
#  'clichés': np.int64(442),
#  'filmmakers': np.int64(1003),
#  'far': np.int64(968),
#  'tragic': np.int64(2732),
#  'merit': np.int64(1658),
#  'superficial': np.int64(2595),
#  'treatment': np.int64(2745),
#  'demonstrate': np.int64(661),
#  'director': np.int64(703),
#  'hollywood': np.int64(1255),
#  'game': np.int64(1091),
#  'turn': np.int64(2766),
#  'small': np.int64(2418),
#  'personal': np.int64(1902),
#  'film': np.int64(1001),
#  'emotional': np.int64(818),
#  'wallop': np.int64(2895),
#  'depress': np.int64(668),
#  'poetry': np.int64(1951),
#  'deeply': np.int64(642),
#  'think': np.int64(2685),
#  'absurd': np.int64(21),
#  'moviegoers': np.int64(1714),
#  'nt': np.int64(1782),
#  'make': np.int64(1598),
#  'movies': np.int64(1717),
#  'like': np.int64(1540),
#  'use': np.int64(2841),
#  'happen': np.int64(1193),
#  'saw': np.int64(2261),
#  'bad': np.int64(194),
#  'movie': np.int64(1713),
#  'lend': np.int64(1521),
#  'dignity': np.int64(696),
#  'dumb': np.int64(771),
#  'story': np.int64(2533),
#  'greatest': np.int64(1154),
#  'musicians': np.int64(1728),
#  'cold': np.int64(459),
#  'usual': np.int64(2843),
#  'intelligence': np.int64(1397),
#  'subtlety': np.int64(2575),
#  'redundant': np.int64(2126),
#  'concept': np.int64(503),
#  'swim': np.int64(2622),
#  'young': np.int64(2995),
#  'woman': np.int64(2962),
#  'face': np.int64(946),
#  'cast': np.int64(356),
#  'actress': np.int64(44),
#  'project': np.int64(2038),
#  'doubt': np.int64(742),
#  'succeed': np.int64(2578),
#  'equal': np.int64(865),
#  'original': np.int64(1823),
#  'ways': np.int64(2911),
#  'better': np.int64(233),
#  'black': np.int64(247),
#  'camp': np.int64(338),
#  'conspiracy': np.int64(525),
#  'dirty': np.int64(707),
#  'smile': np.int64(2423),
#  'come': np.int64(467),
#  'performances': np.int64(1896),
#  'unfunny': np.int64(2810),
#  'mix': np.int64(1685),
#  'antic': np.int64(115),
#  'spirit': np.int64(2482),
#  'half': np.int64(1183),
#  'dragonfly': np.int64(749),
#  'worse': np.int64(2975),
#  'world': np.int64(2973),
#  'cinema': np.int64(419),
#  'good': np.int64(1131),
#  'view': np.int64(2867),
#  'alternative': np.int64(86),
#  'plot': np.int64(1946),
#  'start': np.int64(2505),
#  'finish': np.int64(1012),
#  'action': np.int64(40),
#  'stilted': np.int64(2521),
#  'cylinders': np.int64(605),
#  'little': np.int64(1552),
#  'preachy': np.int64(1994),
#  'poorly': np.int64(1969),
#  'act': np.int64(39),
#  'year': np.int64(2989),
#  'sit': np.int64(2389),
#  'best': np.int64(232),
#  'man': np.int64(1602),
#  'weave': np.int64(2914),
#  'theme': np.int64(2682),
#  'funny': np.int64(1084),
#  'issue': np.int64(1427),
#  'adults': np.int64(57),
#  'marriage': np.int64(1613),
#  'real': np.int64(2101),
#  'silly': np.int64(2373),
#  'crude': np.int64(590),
#  'storyline': np.int64(2534),
#  'heroes': np.int64(1225),
#  'existence': np.int64(914),
#  'entire': np.int64(859),
#  'point': np.int64(1954),
#  'dog': np.int64(739),
#  'course': np.int64(561),
#  'classic': np.int64(428),
#  'sense': np.int64(2313),
#  'dry': np.int64(766),
#  'recycle': np.int64(2121),
#  'time': np.int64(2701),
#  'care': np.int64(347),
#  'count': np.int64(557),
#  'cover': np.int64(562),
#  'territory': np.int64(2670),
#  'originality': np.int64(1824),
#  'suggest': np.int64(2587),
#  'feature': np.int64(986),
#  'million': np.int64(1672),
#  'version': np.int64(2860),
#  'gorgeous': np.int64(1135),
#  'deceptively': np.int64(637),
#  'minimalist': np.int64(1676),
#  'cross': np.int64(587),
#  'prove': np.int64(2046),
#  'lose': np.int64(1566),
#  'touch': np.int64(2721),
#  'bring': np.int64(300),
#  'superb': np.int64(2594),
#  'performance': np.int64(1895),
#  'middle': np.int64(1664),
#  'muddle': np.int64(1720),
#  'splash': np.int64(2485),
#  'bloody': np.int64(261),
#  'beauty': np.int64(219),
#  'vivid': np.int64(2885),
#  'scorsese': np.int64(2280),
#  'pointless': np.int64(1955),
#  'beautifully': np.int64(218),
#  'contrive': np.int64(539),
#  'situations': np.int64(2392),
#  'poor': np.int64(1968),
#  'drive': np.int64(760),
#  'subtle': np.int64(2573),
#  'son': np.int64(2443),
#  'room': np.int64(2221),
#  'sophisticate': np.int64(2447),
#  'rich': np.int64(2195),
#  'vein': np.int64(2857),
#  'stuff': np.int64(2557),
#  'apparent': np.int64(121),
#  'joy': np.int64(1451),
#  'shoot': np.int64(2357),
#  'ugly': np.int64(2772),
#  'digital': np.int64(695),
#  'video': np.int64(2865),
#  'sour': np.int64(2459),
#  'core': np.int64(551),
#  'exploration': np.int64(928),
#  'emptiness': np.int64(827),
#  'end': np.int64(831),
#  'hold': np.int64(1250),
#  'thrill': np.int64(2691),
#  'pretty': np.int64(2011),
#  'damn': np.int64(610),
#  'feel': np.int64(989),
#  'lousy': np.int64(1571),
#  'record': np.int64(2119),
#  'industry': np.int64(1359),
#  'current': np.int64(600),
#  'magnificent': np.int64(1592),
#  'swoop': np.int64(2624),
#  'shots': np.int64(2359),
#  'breathtaking': np.int64(290),
#  'overall': np.int64(1830),
#  'experience': np.int64(923),
#  'sound': np.int64(2457),
#  'cruel': np.int64(592),
#  'carry': np.int64(351),
#  'men': np.int64(1651),
#  'marginal': np.int64(1610),
#  'ideas': np.int64(1301),
#  'women': np.int64(2963),
#  'total': np.int64(2719),
#  'lack': np.int64(1488),
#  'empathy': np.int64(821),
#  'fresh': np.int64(1069),
#  'history': np.int64(1246),
#  'eastwood': np.int64(787),
#  'pay': np.int64(1884),
#  'earnest': np.int64(780),
#  'homage': np.int64(1258),
#  'weak': np.int64(2912),
#  'skip': np.int64(2397),
#  'laugh': np.int64(1505),
#  'surprise': np.int64(2605),
#  'affirm': np.int64(64),
#  'power': np.int64(1988),
#  'help': np.int64(1222),
#  'people': np.int64(1889),
#  'endure': np.int64(836),
#  'unimaginable': np.int64(2811),
#  'horror': np.int64(1274),
#  'absolute': np.int64(17),
#  'generate': np.int64(1103),
#  'life': np.int64(1531),
#  'fun': np.int64(1081),
#  'low': np.int64(1575),
#  'base': np.int64(210),
#  'true': np.int64(2757),
#  'historically': np.int64(1245),
#  'significant': np.int64(2370),
#  'tribute': np.int64(2749),
#  'actors': np.int64(43),
#  'throw': np.int64(2694),
#  'spark': np.int64(2465),
#  'appear': np.int64(124),
#  'ca': np.int64(330),
#  'heat': np.int64(1215),
#  'comedy': np.int64(471),
#  'robert': np.int64(2208),
#  'deniro': np.int64(663),
#  'manage': np.int64(1603),
#  'terrific': np.int64(2668),
#  'flair': np.int64(1022),
#  'farce': np.int64(969),
#  'family': np.int64(961),
#  'intensity': np.int64(1402),
#  'fashion': np.int64(973),
#  'engross': np.int64(842),
#  'entertainment': np.int64(855),
#  'animate': np.int64(110),
#  'write': np.int64(2982),
#  'believe': np.int64(225),
#  'central': np.int64(367),
#  'creation': np.int64(572),
#  'comic': np.int64(475),
#  'parody': np.int64(1867),
#  'melodrama': np.int64(1645),
#  'toss': np.int64(2718),
#  'intrigue': np.int64(1413),
#  'question': np.int64(2072),
#  'difference': np.int64(692),
#  'moments': np.int64(1690),
#  'generous': np.int64(1106),
#  'subversive': np.int64(2577),
#  'follow': np.int64(1040),
#  'stale': np.int64(2500),
#  'standard': np.int64(2502),
#  'explore': np.int64(929),
#  'underbelly': np.int64(2790),
#  'criminal': np.int64(583),
#  'overbear': np.int64(1831),
#  'overthetop': np.int64(1837),
#  'duvall': np.int64(773),
#  'sudden': np.int64(2583),
#  'direct': np.int64(700),
#  'clear': np.int64(432),
#  'washington': np.int64(2904),
#  'certainly': np.int64(371),
#  'career': np.int64(348),
#  'ahead': np.int64(70),
#  'memory': np.int64(1650),
#  'respectable': np.int64(2178),
#  'grate': np.int64(1149),
#  'hate': np.int64(1204),
#  'tear': np.int64(2645),
#  'eye': np.int64(944),
#  'away': np.int64(186),
#  'image': np.int64(1310),
#  'long': np.int64(1561),
#  'read': np.int64(2100),
#  'subtitle': np.int64(2572),
#  'addition': np.int64(51),
#  'sport': np.int64(2492),
#  'title': np.int64(2707),
#  'recent': np.int64(2113),
#  'cinematic': np.int64(420),
#  'generally': np.int64(1102),
#  'quite': np.int64(2079),
#  'build': np.int64(319),
#  'theater': np.int64(2677),
#  'late': np.int64(1502),
#  'mystery': np.int64(1731),
#  'science': np.int64(2274),
#  'killer': np.int64(1472),
#  'website': np.int64(2916),
#  'work': np.int64(2972),
#  'concert': np.int64(505),
#  'direction': np.int64(701),
#  'fluid': np.int64(1036),
#  'nononsense': np.int64(1770),
#  'authority': np.int64(180),
#  'seal': np.int64(2292),
#  'deal': np.int64(629),
#  'step': np.int64(2514),
#  'harsh': np.int64(1200),
#  'piece': np.int64(1923),
#  'storytelling': np.int64(2535),
#  'attractive': np.int64(175),
#  'talented': np.int64(2631),
#  'landscape': np.int64(1493),
#  'create': np.int64(571),
#  'wickedly': np.int64(2939),
#  'watch': np.int64(2906),
#  'provide': np.int64(2047),
#  'pleasures': np.int64(1942),
#  'altogether': np.int64(87),
#  'slight': np.int64(2406),
#  'kind': np.int64(1473),
#  'masterpiece': np.int64(1625),
#  'maybe': np.int64(1631),
#  'twice': np.int64(2768),
#  'completely': np.int64(492),
#  'forget': np.int64(1047),
#  'car': np.int64(346),
#  'park': np.int64(1865),
#  'lot': np.int64(1569),
#  'charm': np.int64(385),
#  'quirky': np.int64(2078),
#  'match': np.int64(1626),
#  'pure': np.int64(2062),
#  'old': np.int64(1809),
#  'college': np.int64(462),
#  'try': np.int64(2762),
#  'wellwritten': np.int64(2930),
#  'wellacted': np.int64(2926),
#  'answer': np.int64(113),
#  'clumsy': np.int64(455),
#  'dialogue': np.int64(689),
#  'heavyhanded': np.int64(1218),
#  'sentiment': np.int64(2319),
#  'lovely': np.int64(1573),
#  'trifle': np.int64(2751),
#  'unfortunately': np.int64(2808),
#  'cuteness': np.int64(604),
#  'budget': np.int64(317),
#  'surprisingly': np.int64(2606),
#  'shoddy': np.int64(2356),
#  'proper': np.int64(2040),
#  'conviction': np.int64(546),
#  'role': np.int64(2213),
#  'jason': np.int64(1438),
#  'bourne': np.int64(279),
#  'great': np.int64(1152),
#  'poignant': np.int64(1953),
#  'artist': np.int64(144),
#  'years': np.int64(2991),
#  'effort': np.int64(799),
#  'share': np.int64(2347),
#  'impressions': np.int64(1330),
#  'loss': np.int64(1568),
#  'art': np.int64(138),
#  'supremely': np.int64(2599),
#  'lively': np.int64(1554),
#  'engage': np.int64(840),
#  'examination': np.int64(895),
#  'similar': np.int64(2374),
#  'irritate': np.int64(1426),
#  'collapse': np.int64(460),
#  'challenge': np.int64(373),
#  'forgive': np.int64(1049),
#  'flaw': np.int64(1028),
#  'serve': np.int64(2328),
#  'learn': np.int64(1516),
#  'tool': np.int64(2714),
#  'way': np.int64(2910),
#  'big': np.int64(235),
#  'excuse': np.int64(908),
#  'play': np.int64(1935),
#  'scene': np.int64(2268),
#  'effective': np.int64(797),
#  'stick': np.int64(2519),
#  'tradition': np.int64(2726),
#  'familial': np.int64(958),
#  'community': np.int64(483),
#  'deliver': np.int64(656),
#  'promise': np.int64(2039),
#  'look': np.int64(1563),
#  'wild': np.int64(2942),
#  'ride': np.int64(2199),
#  'set': np.int64(2330),
#  'cell': np.int64(364),
#  'phone': np.int64(1911),
#  'sketchy': np.int64(2394),
#  'business': np.int64(327),
#  'suppose': np.int64(2598),
#  'absolutely': np.int64(18),
#  'ridiculous': np.int64(2200),
#  'tasteful': np.int64(2640),
#  'rock': np.int64(2210),
#  'roll': np.int64(2215),
#  'suspense': np.int64(2613),
#  'realistic': np.int64(2103),
#  'portrayal': np.int64(1976),
#  'grab': np.int64(1139),
#  'lump': np.int64(1581),
#  'squeeze': np.int64(2497),
#  'stunt': np.int64(2559),
#  'reveal': np.int64(2185),
#  'important': np.int64(1326),
#  'special': np.int64(2469),
#  'talents': np.int64(2632),
#  'service': np.int64(2329),
#  'welcome': np.int64(2925),
#  'relief': np.int64(2149),
#  'filmmaking': np.int64(1004),
#  'easily': np.int64(786),
#  'wait': np.int64(2890),
#  'justify': np.int64(1461),
#  'theatrical': np.int64(2679),
#  'death': np.int64(630),
#  'extraordinary': np.int64(941),
#  'faith': np.int64(953),
#  'heart': np.int64(1210),
#  'adaptation': np.int64(49),
#  'sure': np.int64(2600),
#  'salton': np.int64(2245),
#  'sea': np.int64(2290),
#  'noir': np.int64(1765),
#  'tight': np.int64(2700),
#  'nasty': np.int64(1738),
#  'overlong': np.int64(1835),
#  'bombastic': np.int64(270),
#  'derivative': np.int64(670),
#  'audacious': np.int64(176),
#  'outrageous': np.int64(1826),
#  'disney': np.int64(721),
#  'sequel': np.int64(2323),
#  'final': np.int64(1005),
#  'suck': np.int64(2582),
#  'despite': np.int64(679),
#  'eat': np.int64(789),
#  'argue': np.int64(133),
#  'fight': np.int64(999),
#  'problem': np.int64(2022),
#  'ambition': np.int64(92),
#  'compel': np.int64(488),
#  'picture': np.int64(1920),
#  'run': np.int64(2228),
#  'mere': np.int64(1656),
#  'minutes': np.int64(1678),
#  'remarkable': np.int64(2153),
#  'procession': np.int64(2027),
#  'sweep': np.int64(2618),
#  'romance': np.int64(2218),
#  'genre': np.int64(1108),
#  'date': np.int64(618),
#  'imax': np.int64(1315),
#  'short': np.int64(2358),
#  'pleasant': np.int64(1938),
#  'ooze': np.int64(1814),
#  'involve': np.int64(1419),
#  'save': np.int64(2258),
#  'dash': np.int64(617),
#  'slightest': np.int64(2407),
#  'wildly': np.int64(2944),
#  'uneven': np.int64(2798),
#  'poke': np.int64(1956),
#  'provoke': np.int64(2049),
#  'spear': np.int64(2468),
#  'music': np.int64(1726),
#  'videos': np.int64(2866),
#  'content': np.int64(532),
#  '90': np.int64(12),
#  'want': np.int64(2898),
#  'color': np.int64(463),
#  'depth': np.int64(669),
#  'ingenious': np.int64(1367),
#  'able': np.int64(16),
#  'hit': np.int64(1247),
#  'trouble': np.int64(2756),
#  'day': np.int64(623),
#  'note': np.int64(1777),
#  'sciencefiction': np.int64(2275),
#  'narrative': np.int64(1734),
#  'style': np.int64(2561),
#  'frustrate': np.int64(1077),
#  'difficult': np.int64(694),
#  'unpredictable': np.int64(2826),
#  'scream': np.int64(2283),
#  'ii': np.int64(1307),
#  'achieve': np.int64(36),
#  'ultimate': np.int64(2773),
#  'scifi': np.int64(2276),
#  'spectacle': np.int64(2471),
#  'epic': np.int64(862),
#  'fan': np.int64(963),
#  'hardly': np.int64(1197),
#  'ask': np.int64(153),
#  'plod': np.int64(1945),
#  'dramas': np.int64(752),
#  'reach': np.int64(2098),
#  'translation': np.int64(2737),
#  'speak': np.int64(2467),
#  'force': np.int64(1044),
#  'ponder': np.int64(1965),
#  'space': np.int64(2462),
#  'large': np.int64(1497),
#  'considerable': np.int64(523),
#  'aplomb': np.int64(119),
#  'cobble': np.int64(456),
#  'largely': np.int64(1498),
#  'flat': np.int64(1026),
#  'inane': np.int64(1338),
#  'awful': np.int64(188),
#  'tell': np.int64(2658),
#  'scatter': np.int64(2266),
#  'chance': np.int64(375),
#  'bold': np.int64(269),
#  'studio': np.int64(2555),
#  'standards': np.int64(2503),
#  'actually': np.int64(47),
#  'effect': np.int64(796),
#  'thing': np.int64(2683),
#  'fear': np.int64(982),
#  'mess': np.int64(1660),
#  'infuse': np.int64(1366),
#  'path': np.int64(1877),
#  'flash': np.int64(1024),
#  'warmth': np.int64(2901),
#  'gentle': np.int64(1109),
#  'humor': np.int64(1286),
#  'sensitive': np.int64(2316),
#  'script': np.int64(2289),
#  'avoid': np.int64(183),
#  'pitfalls': np.int64(1929),
#  'expect': np.int64(919),
#  'potentially': np.int64(1985),
#  'setup': np.int64(2332),
#  'load': np.int64(1555),
#  'credit': np.int64(578),
#  'girl': np.int64(1119),
#  'bar': np.int64(205),
#  'enjoy': np.int64(844),
#  'add': np.int64(50),
#  'dark': np.int64(614),
#  'predecessors': np.int64(1998),
#  'yes': np.int64(2992),
#  'pace': np.int64(1842),
#  'extremely': np.int64(943),
#  'unpleasant': np.int64(2825),
#  'entirely': np.int64(860),
#  'performers': np.int64(1897),
#  'affair': np.int64(61),
#  'incredibly': np.int64(1353),
#  'things': np.int64(2684),
#  'predictable': np.int64(1999),
#  'brilliant': np.int64(297),
#  'entertain': np.int64(854),
#  'professional': np.int64(2033),
#  'unassuming': np.int64(2777),
#  'technically': np.int64(2647),
#  'positive': np.int64(1977),
#  'change': np.int64(376),
#  'tone': np.int64(2712),
#  'beat': np.int64(216),
#  'goofy': np.int64(1134),
#  'teem': np.int64(2651),
#  'kid': np.int64(1468),
#  'inside': np.int64(1378),
#  'laughable': np.int64(1506),
#  'watchable': np.int64(2907),
#  'length': np.int64(1522),
#  'value': np.int64(2849),
#  'respect': np.int64(2177),
#  'term': np.int64(2665),
#  'dentist': np.int64(664),
#  'honest': np.int64(1260),
#  'emotions': np.int64(820),
#  'amazingly': np.int64(90),
#  'lame': np.int64(1491),
#  'straightforward': np.int64(2537),
#  'disappointingly': np.int64(709),
#  'slice': np.int64(2404),
#  'gem': np.int64(1100),
#  'delightful': np.int64(654),
#  'spare': np.int64(2464),
#  'photography': np.int64(1914),
#  'understand': np.int64(2793),
#  'plain': np.int64(1933),
#  'structure': np.int64(2552),
#  'frida': np.int64(1071),
#  'different': np.int64(693),
#  'adventurous': np.int64(60),
#  'indian': np.int64(1355),
#  'market': np.int64(1612),
#  'worth': np.int64(2977),
#  'price': np.int64(2014),
#  'gory': np.int64(1137),
#  'mayhem': np.int64(1632),
#  'idea': np.int64(1297),
#  'produce': np.int64(2028),
#  'jerry': np.int64(1442),
#  'bruckheimer': np.int64(312),
#  'reflect': np.int64(2131),
#  'shallow': np.int64(2340),
#  'motivate': np.int64(1708),
#  'target': np.int64(2638),
#  'blair': np.int64(249),
#  'witch': np.int64(2955),
#  'footage': np.int64(1043),
#  'second': np.int64(2296),
#  'tedious': np.int64(2649),
#  'offer': np.int64(1807),
#  'oscar': np.int64(1825),
#  'nomination': np.int64(1767),
#  'esther': np.int64(878),
#  'unusual': np.int64(2833),
#  'stylish': np.int64(2562),
#  'exercise': np.int64(911),
#  'halfway': np.int64(1184),
#  'begin': np.int64(220),
#  'easy': np.int64(788),
#  'border': np.int64(274),
#  'thoroughly': np.int64(2686),
#  'grip': np.int64(1162),
#  'hard': np.int64(1196),
#  'fascinate': np.int64(972),
#  'gun': np.int64(1176),
#  'martial': np.int64(1615),
#  'arts': np.int64(149),
#  'computer': np.int64(500),
#  'camera': np.int64(337),
#  'breezy': np.int64(292),
#  'distract': np.int64(730),
#  'rhythms': np.int64(2194),
#  'sumptuous': np.int64(2591),
#  'stream': np.int64(2541),
#  'slick': np.int64(2405),
#  'manufacture': np.int64(1609),
#  'claim': np.int64(424),
#  'street': np.int64(2542),
#  'credibility': np.int64(576),
#  'nicely': np.int64(1757),
#  'perform': np.int64(1894),
#  'actresses': np.int64(45),
#  'valuable': np.int64(2848),
#  'message': np.int64(1661),
#  'thank': np.int64(2676),
#  'guy': np.int64(1178),
#  'desperately': np.int64(677),
#  'tarantino': np.int64(2637),
#  'grow': np.int64(1168),
#  'essentially': np.int64(876),
#  'collection': np.int64(461),
#  'bits': np.int64(243),
#  'rest': np.int64(2180),
#  'elevate': np.int64(809),
#  'hugh': np.int64(1282),
#  'grant': np.int64(1146),
#  'line': np.int64(1545),
#  'arrive': np.int64(137),
#  'early': np.int64(778),
#  'stay': np.int64(2512),
#  'genuine': np.int64(1111),
#  'insight': np.int64(1379),
#  'urban': np.int64(2839),
#  'hours': np.int64(1277),
#  'john': np.int64(1445),
#  'artful': np.int64(139),
#  'blue': np.int64(263),
#  'green': np.int64(1157),
#  'brown': np.int64(310),
#  'crime': np.int64(581),
#  'include': np.int64(1342),
#  'lane': np.int64(1494),
#  'richard': np.int64(2196),
#  'ludicrous': np.int64(1579),
#  'steven': np.int64(2518),
#  'seagal': np.int64(2291),
#  'warm': np.int64(2900),
#  'water': np.int64(2908),
#  'red': np.int64(2122),
#  'bridge': np.int64(293),
#  'celebration': np.int64(363),
#  'energy': np.int64(839),
#  'heal': np.int64(1208),
#  'sensational': np.int64(2312),
#  'reallife': np.int64(2106),
#  'metaphor': np.int64(1662),
#  'home': np.int64(1259),
#  'leave': np.int64(1517),
#  'mention': np.int64(1655),
#  'retain': np.int64(2182),
#  'resonance': np.int64(2174),
#  'format': np.int64(1051),
#  'oldfashioned': np.int64(1811),
#  'viewers': np.int64(2869),
#  'word': np.int64(2971),
#  'handsome': np.int64(1192),
#  'unfulfilling': np.int64(2809),
#  'drama': np.int64(751),
#  'charmless': np.int64(387),
#  'haunt': np.int64(1205),
#  'debut': np.int64(633),
#  'fine': np.int64(1008),
#  'aim': np.int64(72),
#  'mainly': np.int64(1594),
#  'plenty': np.int64(1943),
#  'grownups': np.int64(1170),
#  'seat': np.int64(2295),
#  'girls': np.int64(1120),
#  'observation': np.int64(1792),
#  'secondhand': np.int64(2297),
#  'familiar': np.int64(959),
#  'spot': np.int64(2493),
#  'players': np.int64(1936),
#  'gift': np.int64(1118),
#  'beings': np.int64(223),
#  'contribution': np.int64(537),
#  'choppy': np.int64(412),
#  'high': np.int64(1232),
#  'school': np.int64(2272),
#  'sex': np.int64(2335),
#  'demand': np.int64(658),
#  'receive': np.int64(2112),
#  'excellent': np.int64(900),
#  'blast': np.int64(254),
#  'escapism': np.int64(873),
#  'merely': np.int64(1657),
#  'kick': np.int64(1467),
#  'culture': np.int64(596),
#  'horrify': np.int64(1273),
#  'tragedies': np.int64(2730),
#  'private': np.int64(2019),
#  'scenes': np.int64(2270),
#  'gain': np.int64(1090),
#  'momentum': np.int64(1691),
#  'sand': np.int64(2246),
#  'pale': np.int64(1851),
#  'characteristic': np.int64(380),
#  'jaglom': np.int64(1433),
#  'honestly': np.int64(1261),
#  'affect': np.int64(62),
#  'sorvino': np.int64(2452),
#  'limitations': np.int64(1543),
#  'classical': np.int64(429),
#  'successful': np.int64(2580),
#  'level': np.int64(1527),
#  'intelligent': np.int64(1398),
#  'accomplish': np.int64(31),
#  'sequels': np.int64(2324),
#  'approach': np.int64(127),
#  'celebrate': np.int64(362),
#  'irish': np.int64(1421),
#  'exhilarate': np.int64(912),
#  'bind': np.int64(239),
#  'appeal': np.int64(123),
#  'trashy': np.int64(2741),
#  'trash': np.int64(2740),
#  'right': np.int64(2201),
#  'summer': np.int64(2590),
#  'sustain': np.int64(2615),
#  'endear': np.int64(832),
#  'days': np.int64(624),
#  'especially': np.int64(874),
#  'ambitious': np.int64(93),
#  'filmmaker': np.int64(1002),
#  'process': np.int64(2026),
#  'subject': np.int64(2566),
#  'matter': np.int64(1628),
#  'incompetent': np.int64(1345),
#  'conclusion': np.int64(507),
#  'wilde': np.int64(2943),
#  'droll': np.int64(761),
#  'whimsy': np.int64(2934),
#  'overcome': np.int64(1833),
#  'parker': np.int64(1866),
#  'creative': np.int64(573),
#  'root': np.int64(2222),
#  'fate': np.int64(978),
#  'casual': np.int64(357),
#  'ode': np.int64(1803),
#  'walk': np.int64(2892),
#  'horrible': np.int64(1271),
#  'terrible': np.int64(2666),
#  'stage': np.int64(2499),
#  'screen': np.int64(2284),
#  'ellen': np.int64(811),
#  'pompeo': np.int64(1964),
#  'giant': np.int64(1116),
#  'copy': np.int64(550),
#  'excite': np.int64(905),
#  'interview': np.int64(1407),
#  'evocative': np.int64(889),
#  'decades': np.int64(634),
#  'ago': np.int64(69),
#  'fail': np.int64(949),
#  'catch': np.int64(358),
#  'company': np.int64(484),
#  'astonish': np.int64(163),
#  'growth': np.int64(1171),
#  'freeze': np.int64(1065),
#  'soap': np.int64(2429),
#  'opera': np.int64(1818),
#  'simply': np.int64(2381),
#  'free': np.int64(1063),
#  'tv': np.int64(2767),
#  'giddy': np.int64(1117),
#  'choose': np.int64(410),
#  'purely': np.int64(2063),
#  'enjoyable': np.int64(845),
#  'open': np.int64(1816),
#  'suffer': np.int64(2584),
#  'failure': np.int64(950),
#  'hoffman': np.int64(1248),
#  'powerful': np.int64(1989),
#  'clinic': np.int64(444),
#  'wonderful': np.int64(2965),
#  'cinematography': np.int64(421),
#  'highconcept': np.int64(1233),
#  'refuse': np.int64(2136),
#  'reason': np.int64(2108),
#  'confuse': np.int64(515),
#  'need': np.int64(1749),
#  'surreal': np.int64(2607),
#  'resonant': np.int64(2175),
#  'passion': np.int64(1873),
#  'material': np.int64(1627),
#  'formula': np.int64(1052),
#  'wrong': np.int64(2985),
#  'wellcrafted': np.int64(2927),
#  'distance': np.int64(725),
#  'render': np.int64(2160),
#  'cheesy': np.int64(395),
#  'awe': np.int64(187),
#  'joyous': np.int64(1453),
#  'romp': np.int64(2220),
#  'nonstop': np.int64(1773),
#  'hoot': np.int64(1266),
#  'sabotage': np.int64(2233),
#  'torture': np.int64(2717),
#  'argentine': np.int64(132),
#  'remind': np.int64(2156),
#  'feelgood': np.int64(990),
#  'equally': np.int64(866),
#  'spoof': np.int64(2490),
#  'aspects': np.int64(155),
#  'white': np.int64(2936),
#  'package': np.int64(1844),
#  'timely': np.int64(2703),
#  'wrap': np.int64(2981),
#  'generic': np.int64(1105),
#  'crass': np.int64(568),
#  'frame': np.int64(1058),
#  'persona': np.int64(1901),
#  'plight': np.int64(1944),
#  'flamboyant': np.int64(1023),
#  'female': np.int64(992),
#  'cable': np.int64(331),
#  'channel': np.int64(377),
#  'appal': np.int64(120),
#  'amaze': np.int64(89),
#  'spiderman': np.int64(2478),
#  'stomachturning': np.int64(2527),
#  'violence': np.int64(2874),
#  'humanity': np.int64(1285),
#  'undeniable': np.int64(2788),
#  'mr': np.int64(1718),
#  'broomfield': np.int64(307),
#  'continue': np.int64(534),
#  'lesser': np.int64(1523),
#  'thriller': np.int64(2692),
#  'joke': np.int64(1446),
#  'wallace': np.int64(2893),
#  'complex': np.int64(493),
#  'wooden': np.int64(2969),
#  'lowkey': np.int64(1578),
#  'manner': np.int64(1608),
#  'burn': np.int64(324),
#  'strongest': np.int64(2550),
#  'brothers': np.int64(309),
#  'miss': np.int64(1683),
#  'outstanding': np.int64(1828),
#  'potent': np.int64(1983),
#  'seek': np.int64(2301),
#  'excitement': np.int64(906),
#  'insult': np.int64(1391),
#  'problems': np.int64(2024),
#  'fat': np.int64(976),
#  'greek': np.int64(1156),
#  'wed': np.int64(2917),
#  'focus': np.int64(1038),
#  'biopic': np.int64(240),
#  'document': np.int64(736),
#  'male': np.int64(1601),
#  'era': np.int64(870),
#  'signpost': np.int64(2371),
#  'mark': np.int64(1611),
#  'slow': np.int64(2413),
#  'linger': np.int64(1546),
#  'imagination': np.int64(1312),
#  'quirk': np.int64(2077),
#  'irrelevant': np.int64(1424),
#  'gradually': np.int64(1143),
#  'korean': np.int64(1484),
#  '2002': np.int64(6),
#  'historical': np.int64(1244),
#  'solid': np.int64(2436),
#  'assure': np.int64(162),
#  'complete': np.int64(491),
#  'modern': np.int64(1687),
#  'irony': np.int64(1423),
#  'road': np.int64(2207),
#  'thematic': np.int64(2680),
#  'obvious': np.int64(1796),
#  'sexual': np.int64(2336),
#  'politics': np.int64(1963),
#  'smug': np.int64(2424),
#  'formulaic': np.int64(1053),
#  'capture': np.int64(345),
#  'live': np.int64(1553),
#  'deserve': np.int64(672),
#  'pass': np.int64(1872),
#  'stupid': np.int64(2560),
#  'elements': np.int64(808),
#  'powerfully': np.int64(1990),
#  'mood': np.int64(1697),
#  'combine': np.int64(466),
#  'malaise': np.int64(1600),
#  'felt': np.int64(991),
#  'weird': np.int64(2922),
#  'finally': np.int64(1007),
#  'offensive': np.int64(1806),
#  'santa': np.int64(2250),
#  'children': np.int64(401),
#  'emotionally': np.int64(819),
#  'intimate': np.int64(1409),
#  'wish': np.int64(2953),
#  'loose': np.int64(1564),
#  'lazy': np.int64(1511),
#  'suspenseful': np.int64(2614),
#  'crackle': np.int64(564),
#  'fairly': np.int64(952),
#  'study': np.int64(2556),
#  'main': np.int64(1593),
#  'genial': np.int64(1107),
#  'job': np.int64(1444),
#  'husband': np.int64(1292),
#  'cliché': np.int64(440),
#  'book': np.int64(273),
#  'nonsensical': np.int64(1772),
#  'darker': np.int64(615),
#  'misogyny': np.int64(1682),
#  'suffocate': np.int64(2585),
#  'chill': np.int64(402),
#  'heartwarming': np.int64(1214),
#  'retread': np.int64(2183),
#  'reef': np.int64(2127),
#  'break': np.int64(286),
#  'deep': np.int64(640),
#  'deceptions': np.int64(636),
#  'unsettle': np.int64(2829),
#  'grand': np.int64(1144),
#  'goodnatured': np.int64(1133),
#  'audience': np.int64(177),
#  'nuanced': np.int64(1784),
#  'lead': np.int64(1512),
#  'star': np.int64(2504),
#  'selfindulgent': np.int64(2308),
#  'idiots': np.int64(1305),
#  'mental': np.int64(1654),
#  'punk': np.int64(2061),
#  'medium': np.int64(1643),
#  'hole': np.int64(1251),
#  'gap': np.int64(1094),
#  'pilot': np.int64(1925),
#  'team': np.int64(2644),
#  'blend': np.int64(257),
#  'chabrol': np.int64(372),
#  'master': np.int64(1622),
#  'innuendo': np.int64(1375),
#  'rivet': np.int64(2206),
#  'war': np.int64(2899),
#  'screenplay': np.int64(2285),
#  'bore': np.int64(275),
#  'mesmerize': np.int64(1659),
#  'thoughtful': np.int64(2687),
#  'raw': np.int64(2097),
#  'comingofage': np.int64(476),
#  'tale': np.int64(2629),
#  'drug': np.int64(764),
#  'testament': np.int64(2672),
#  ...}

# %%
# Calculate statistical similarity
sim_5_100_bow = cosine_similarity(train_bow_lemma[4].toarray()[0],
                             train_bow_lemma[99].toarray()[0])
sim_5_15000_bow = cosine_similarity(train_bow_lemma[4].toarray()[0],
                               train_bow_lemma[14999].toarray()[0])
sim_5_50000_bow = cosine_similarity(train_bow_lemma[4].toarray()[0],
                               train_bow_lemma[49999].toarray()[0])

# %%
print(f"{lemma_train[4]} \n {sim_5_100_bow} \n {lemma_train[99]}")
# Out:
# worst revengeofthenerds clichés filmmakers could dredge
#  0.0
#  act direct clear washington certainly new career ahead

# %%
print(f"{lemma_train[4]} \n {sim_5_15000_bow} \n {lemma_train[14999]}")
# Out:
# worst revengeofthenerds clichés filmmakers could dredge
#  0.0
#  eloquent

# %%
print(f"{lemma_train[4]} \n {sim_5_50000_bow} \n {lemma_train[49999]}")
# Out:
# worst revengeofthenerds clichés filmmakers could dredge
#  0.0
#  stylish

# %% [markdown]
# **stemmed sentences**

# %%
# Calculate BoW - stemmed sentences
train_bow_stem = count_vectorizer.fit_transform(stem_train) # Learn vocabulary from training
val_bow_stem = count_vectorizer.transform(stem_val) # Apply to validation

# %%
# Get vocabulary and tokens after fitting
vocabulary_bow = count_vectorizer.vocabulary_
tokens_bow = count_vectorizer.get_feature_names_out()

# %%
vocabulary_bow
# Out:
# {'hide': np.int64(1228),
#  'new': np.int64(1757),
#  'secret': np.int64(2283),
#  'parent': np.int64(1870),
#  'unit': np.int64(2817),
#  'contain': np.int64(539),
#  'wit': np.int64(2954),
#  'labor': np.int64(1484),
#  'gag': np.int64(1087),
#  'love': np.int64(1573),
#  'charact': np.int64(395),
#  'commun': np.int64(490),
#  'someth': np.int64(2431),
#  'beauti': np.int64(226),
#  'human': np.int64(1278),
#  'natur': np.int64(1747),
#  'remain': np.int64(2136),
#  'utterli': np.int64(2846),
#  'satisfi': np.int64(2240),
#  'worst': np.int64(2974),
#  'cliché': np.int64(452),
#  'filmmak': np.int64(1002),
#  'far': np.int64(967),
#  'tragic': np.int64(2731),
#  'merit': np.int64(1658),
#  'superfici': np.int64(2596),
#  'treatment': np.int64(2745),
#  'demonstr': np.int64(671),
#  'director': np.int64(714),
#  'hollywood': np.int64(1252),
#  'blockbust': np.int64(266),
#  'game': np.int64(1089),
#  'turn': np.int64(2767),
#  'small': np.int64(2405),
#  'person': np.int64(1905),
#  'film': np.int64(1001),
#  'emot': np.int64(830),
#  'wallop': np.int64(2891),
#  'depress': np.int64(680),
#  'poetri': np.int64(1955),
#  'deepli': np.int64(652),
#  'thought': np.int64(2687),
#  'goe': np.int64(1125),
#  'absurd': np.int64(25),
#  'length': np.int64(1523),
#  'moviego': np.int64(1725),
#  'nt': np.int64(1792),
#  'make': np.int64(1602),
#  'movi': np.int64(1724),
#  'like': np.int64(1540),
#  'use': np.int64(2842),
#  'noth': np.int64(1785),
#  'happen': np.int64(1189),
#  'saw': np.int64(2247),
#  'bad': np.int64(200),
#  'lend': np.int64(1522),
#  'digniti': np.int64(707),
#  'dumb': np.int64(784),
#  'stori': np.int64(2527),
#  'greatest': np.int64(1150),
#  'musician': np.int64(1737),
#  'cold': np.int64(471),
#  'usual': np.int64(2844),
#  'intellig': np.int64(1390),
#  'subtleti': np.int64(2573),
#  'redund': np.int64(2113),
#  'concept': np.int64(510),
#  'swim': np.int64(2623),
#  'young': np.int64(2994),
#  'woman': np.int64(2961),
#  'face': np.int64(945),
#  'cast': np.int64(371),
#  'actress': np.int64(43),
#  'project': np.int64(2029),
#  'doubt': np.int64(752),
#  'yearn': np.int64(2991),
#  'succe': np.int64(2576),
#  'equal': np.int64(873),
#  'origin': np.int64(1829),
#  'way': np.int64(2909),
#  'better': np.int64(240),
#  'anyth': np.int64(128),
#  'black': np.int64(253),
#  'camp': np.int64(352),
#  'conspiraci': np.int64(534),
#  'dirti': np.int64(717),
#  'smile': np.int64(2410),
#  'come': np.int64(478),
#  'perform': np.int64(1901),
#  'unfunni': np.int64(2811),
#  'piti': np.int64(1933),
#  'imagin': np.int64(1309),
#  'mix': np.int64(1691),
#  'antic': np.int64(123),
#  'spirit': np.int64(2476),
#  'half': np.int64(1179),
#  'dragonfli': np.int64(759),
#  'wors': np.int64(2973),
#  'world': np.int64(2971),
#  'cinema': np.int64(435),
#  'good': np.int64(1127),
#  'view': np.int64(2867),
#  'altern': np.int64(92),
#  'plot': np.int64(1947),
#  'start': np.int64(2499),
#  'finish': np.int64(1007),
#  'action': np.int64(40),
#  'stilt': np.int64(2514),
#  'cylind': np.int64(615),
#  'littl': np.int64(1551),
#  'preachi': np.int64(1989),
#  'poorli': np.int64(1971),
#  'act': np.int64(39),
#  'year': np.int64(2990),
#  'sit': np.int64(2376),
#  'anoth': np.int64(119),
#  'best': np.int64(238),
#  'man': np.int64(1606),
#  'weav': np.int64(2912),
#  'theme': np.int64(2682),
#  'funni': np.int64(1080),
#  'issu': np.int64(1419),
#  'adult': np.int64(59),
#  'marriag': np.int64(1617),
#  'think': np.int64(2685),
#  'real': np.int64(2088),
#  'silli': np.int64(2358),
#  'crude': np.int64(602),
#  'storylin': np.int64(2528),
#  'hero': np.int64(1222),
#  'exist': np.int64(916),
#  'entir': np.int64(867),
#  'point': np.int64(1958),
#  'dog': np.int64(748),
#  'cours': np.int64(574),
#  'nowher': np.int64(1791),
#  'classic': np.int64(445),
#  'everi': np.int64(893),
#  'sens': np.int64(2299),
#  'sometim': np.int64(2432),
#  'dri': np.int64(771),
#  'alreadi': np.int64(91),
#  'recycl': np.int64(2108),
#  'time': np.int64(2700),
#  'care': np.int64(362),
#  'count': np.int64(570),
#  'cover': np.int64(575),
#  'territori': np.int64(2670),
#  'suggest': np.int64(2587),
#  'featur': np.int64(986),
#  '40': np.int64(12),
#  'million': np.int64(1675),
#  'version': np.int64(2860),
#  'gorgeou': np.int64(1131),
#  'decept': np.int64(645),
#  'minimalist': np.int64(1679),
#  'cross': np.int64(598),
#  'prove': np.int64(2038),
#  'lost': np.int64(1569),
#  'touch': np.int64(2723),
#  'bring': np.int64(311),
#  'superb': np.int64(2595),
#  'admittedli': np.int64(55),
#  'middl': np.int64(1667),
#  'disappoint': np.int64(718),
#  'horror': np.int64(1268),
#  'muddl': np.int64(1729),
#  'splash': np.int64(2479),
#  'bloodi': np.int64(269),
#  'vivid': np.int64(2880),
#  'scorses': np.int64(2266),
#  'given': np.int64(1114),
#  'mani': np.int64(1610),
#  'pointless': np.int64(1959),
#  'contriv': np.int64(549),
#  'situat': np.int64(2378),
#  'poor': np.int64(1970),
#  'drive': np.int64(772),
#  'direct': np.int64(712),
#  'subtl': np.int64(2571),
#  'son': np.int64(2435),
#  'room': np.int64(2203),
#  'sophist': np.int64(2438),
#  'rich': np.int64(2176),
#  'vein': np.int64(2857),
#  'stuff': np.int64(2554),
#  'appar': np.int64(132),
#  'joy': np.int64(1446),
#  'shot': np.int64(2344),
#  'ugli': np.int64(2773),
#  'digit': np.int64(706),
#  'video': np.int64(2865),
#  'sour': np.int64(2449),
#  'core': np.int64(563),
#  'explor': np.int64(928),
#  'empti': np.int64(838),
#  'end': np.int64(843),
#  'capabl': np.int64(356),
#  'hold': np.int64(1247),
#  'thrill': np.int64(2690),
#  'pretti': np.int64(2003),
#  'damn': np.int64(620),
#  'feel': np.int64(989),
#  'lousi': np.int64(1572),
#  'record': np.int64(2105),
#  'industri': np.int64(1351),
#  'current': np.int64(611),
#  'togeth': np.int64(2707),
#  'magnific': np.int64(1596),
#  'swoop': np.int64(2625),
#  'breathtak': np.int64(301),
#  'overal': np.int64(1836),
#  'experi': np.int64(923),
#  'sound': np.int64(2447),
#  'cruel': np.int64(604),
#  'carri': np.int64(366),
#  'men': np.int64(1652),
#  'margin': np.int64(1614),
#  'idea': np.int64(1295),
#  'women': np.int64(2962),
#  'total': np.int64(2722),
#  'lack': np.int64(1485),
#  'empathi': np.int64(831),
#  'fresh': np.int64(1067),
#  'histori': np.int64(1242),
#  'eastwood': np.int64(801),
#  'pay': np.int64(1890),
#  'earnest': np.int64(795),
#  'homag': np.int64(1255),
#  'weak': np.int64(2910),
#  'skip': np.int64(2383),
#  'dreck': np.int64(768),
#  'laugh': np.int64(1503),
#  'surpris': np.int64(2607),
#  'affirm': np.int64(65),
#  'power': np.int64(1986),
#  'help': np.int64(1220),
#  'peopl': np.int64(1896),
#  'endur': np.int64(848),
#  'unimagin': np.int64(2812),
#  'absolut': np.int64(22),
#  'gener': np.int64(1100),
#  'life': np.int64(1531),
#  'fun': np.int64(1078),
#  'high': np.int64(1230),
#  'low': np.int64(1575),
#  'base': np.int64(218),
#  'true': np.int64(2760),
#  'histor': np.int64(1241),
#  'signific': np.int64(2356),
#  'tribut': np.int64(2750),
#  'actor': np.int64(42),
#  'throw': np.int64(2692),
#  'spark': np.int64(2455),
#  'appear': np.int64(134),
#  'ca': np.int64(343),
#  'heat': np.int64(1212),
#  'comedi': np.int64(480),
#  'robert': np.int64(2190),
#  'deniro': np.int64(674),
#  'manag': np.int64(1607),
#  'terrif': np.int64(2668),
#  'flair': np.int64(1017),
#  'extrem': np.int64(939),
#  'farc': np.int64(968),
#  'famili': np.int64(960),
#  'intens': np.int64(1392),
#  'fashion': np.int64(973),
#  'engross': np.int64(854),
#  'entertain': np.int64(862),
#  'anim': np.int64(117),
#  'written': np.int64(2985),
#  'believ': np.int64(231),
#  'anyon': np.int64(127),
#  'central': np.int64(382),
#  'creation': np.int64(586),
#  'comic': np.int64(484),
#  'parodi': np.int64(1873),
#  'melodrama': np.int64(1647),
#  'toss': np.int64(2721),
#  'intrigu': np.int64(1404),
#  'question': np.int64(2060),
#  'differ': np.int64(704),
#  'moment': np.int64(1698),
#  'subvers': np.int64(2575),
#  'follow': np.int64(1039),
#  'stale': np.int64(2494),
#  'standard': np.int64(2496),
#  'becom': np.int64(227),
#  'underbelli': np.int64(2789),
#  'crimin': np.int64(595),
#  'overbear': np.int64(1837),
#  'overthetop': np.int64(1844),
#  'duval': np.int64(787),
#  'sudden': np.int64(2583),
#  'wisdom': np.int64(2951),
#  'clear': np.int64(447),
#  'washington': np.int64(2903),
#  'certainli': np.int64(386),
#  'career': np.int64(363),
#  'ahead': np.int64(72),
#  'memori': np.int64(1651),
#  'respect': np.int64(2160),
#  'grate': np.int64(1145),
#  'showcas': np.int64(2347),
#  'hate': np.int64(1201),
#  'tear': np.int64(2647),
#  'eye': np.int64(941),
#  'away': np.int64(193),
#  'imag': np.int64(1307),
#  'long': np.int64(1561),
#  'read': np.int64(2087),
#  'subtitl': np.int64(2570),
#  'addit': np.int64(50),
#  'sport': np.int64(2486),
#  'titl': np.int64(2705),
#  'recent': np.int64(2099),
#  'cinemat': np.int64(436),
#  'quit': np.int64(2067),
#  'build': np.int64(332),
#  'theater': np.int64(2679),
#  'late': np.int64(1499),
#  'mysteri': np.int64(1739),
#  'scienc': np.int64(2259),
#  'killer': np.int64(1467),
#  'websit': np.int64(2914),
#  'work': np.int64(2970),
#  'concert': np.int64(513),
#  'fluid': np.int64(1034),
#  'nononsens': np.int64(1777),
#  'author': np.int64(185),
#  'harri': np.int64(1194),
#  'seal': np.int64(2277),
#  'deal': np.int64(639),
#  'gone': np.int64(1126),
#  'step': np.int64(2507),
#  'harsh': np.int64(1196),
#  'piec': np.int64(1925),
#  'storytel': np.int64(2529),
#  'attract': np.int64(181),
#  'talent': np.int64(2634),
#  'landscap': np.int64(1490),
#  'creat': np.int64(585),
#  'wickedli': np.int64(2939),
#  'watch': np.int64(2905),
#  'provid': np.int64(2039),
#  'pleasur': np.int64(1943),
#  'altogeth': np.int64(93),
#  'slight': np.int64(2395),
#  'kind': np.int64(1468),
#  'masterpiec': np.int64(1625),
#  'mayb': np.int64(1632),
#  'twice': np.int64(2769),
#  'complet': np.int64(500),
#  'forgotten': np.int64(1048),
#  'car': np.int64(361),
#  'park': np.int64(1871),
#  'lot': np.int64(1570),
#  'charm': np.int64(401),
#  'quirki': np.int64(2066),
#  'match': np.int64(1626),
#  'pure': np.int64(2052),
#  'old': np.int64(1814),
#  'colleg': np.int64(474),
#  'tri': np.int64(2748),
#  'wellwritten': np.int64(2926),
#  'wellact': np.int64(2922),
#  'conclus': np.int64(515),
#  'answer': np.int64(120),
#  'clumsi': np.int64(465),
#  'dialogu': np.int64(700),
#  'heavyhand': np.int64(1215),
#  'sentiment': np.int64(2304),
#  'trifl': np.int64(2752),
#  'unfortun': np.int64(2809),
#  'cute': np.int64(614),
#  'budget': np.int64(330),
#  'betray': np.int64(239),
#  'surprisingli': np.int64(2608),
#  'shoddi': np.int64(2341),
#  'proper': np.int64(2031),
#  'convict': np.int64(556),
#  'role': np.int64(2196),
#  'jason': np.int64(1430),
#  'bourn': np.int64(290),
#  'great': np.int64(1148),
#  'poignant': np.int64(1957),
#  'artist': np.int64(154),
#  'effort': np.int64(814),
#  'share': np.int64(2332),
#  'impress': np.int64(1323),
#  'loss': np.int64(1568),
#  'art': np.int64(149),
#  'suprem': np.int64(2602),
#  'middleag': np.int64(1668),
#  'live': np.int64(1552),
#  'engag': np.int64(852),
#  'examin': np.int64(904),
#  'similar': np.int64(2359),
#  'obsess': np.int64(1801),
#  'irrit': np.int64(1418),
#  'collaps': np.int64(472),
#  'challeng': np.int64(389),
#  'forgiv': np.int64(1047),
#  'flaw': np.int64(1025),
#  'serv': np.int64(2312),
#  'learn': np.int64(1514),
#  'tool': np.int64(2716),
#  'big': np.int64(241),
#  'excus': np.int64(912),
#  'play': np.int64(1938),
#  'scene': np.int64(2253),
#  'effect': np.int64(812),
#  'stick': np.int64(2511),
#  'import': np.int64(1321),
#  'tradit': np.int64(2728),
#  'deliv': np.int64(665),
#  'promis': np.int64(2030),
#  'look': np.int64(1563),
#  'wild': np.int64(2942),
#  'ride': np.int64(2180),
#  'set': np.int64(2314),
#  'cell': np.int64(379),
#  'phone': np.int64(1913),
#  'sketchi': np.int64(2380),
#  'busi': np.int64(341),
#  'suppos': np.int64(2601),
#  'ridicul': np.int64(2181),
#  'tast': np.int64(2641),
#  'rock': np.int64(2193),
#  'roll': np.int64(2197),
#  'suspens': np.int64(2615),
#  'consist': np.int64(531),
#  'realist': np.int64(2090),
#  'portray': np.int64(1977),
#  'grab': np.int64(1136),
#  'lump': np.int64(1584),
#  'squeez': np.int64(2491),
#  'stunt': np.int64(2556),
#  'reveal': np.int64(2167),
#  'special': np.int64(2459),
#  'servic': np.int64(2313),
#  'welcom': np.int64(2921),
#  'relief': np.int64(2135),
#  'easili': np.int64(800),
#  'wait': np.int64(2886),
#  'justifi': np.int64(1456),
#  'theatric': np.int64(2680),
#  'death': np.int64(640),
#  'extraordinari': np.int64(937),
#  'faith': np.int64(955),
#  'seen': np.int64(2287),
#  'heart': np.int64(1208),
#  'adapt': np.int64(47),
#  'sure': np.int64(2603),
#  'salton': np.int64(2230),
#  'sea': np.int64(2275),
#  'noir': np.int64(1772),
#  'tight': np.int64(2699),
#  'nasti': np.int64(1745),
#  'overlong': np.int64(1843),
#  'bombast': np.int64(280),
#  'deriv': np.int64(682),
#  'audaci': np.int64(182),
#  'outrag': np.int64(1832),
#  'disney': np.int64(732),
#  'sequel': np.int64(2306),
#  'final': np.int64(1003),
#  'suck': np.int64(2581),
#  'despit': np.int64(689),
#  'eat': np.int64(802),
#  'argu': np.int64(143),
#  'fight': np.int64(999),
#  'problem': np.int64(2015),
#  'ambit': np.int64(99),
#  'laudabl': np.int64(1502),
#  'compel': np.int64(496),
#  'infecti': np.int64(1356),
#  'pictur': np.int64(1922),
#  'run': np.int64(2212),
#  'mere': np.int64(1657),
#  'minut': np.int64(1681),
#  'remark': np.int64(2138),
#  'process': np.int64(2019),
#  'sweep': np.int64(2620),
#  'romanc': np.int64(2200),
#  'genr': np.int64(1102),
#  'passabl': np.int64(1879),
#  'date': np.int64(628),
#  'imax': np.int64(1310),
#  'short': np.int64(2343),
#  'pleasant': np.int64(1941),
#  'ooz': np.int64(1818),
#  'involv': np.int64(1410),
#  'save': np.int64(2244),
#  'dash': np.int64(627),
#  'slightest': np.int64(2396),
#  'wildli': np.int64(2943),
#  'uneven': np.int64(2800),
#  'poke': np.int64(1960),
#  'provok': np.int64(2041),
#  'spear': np.int64(2458),
#  'music': np.int64(1736),
#  'content': np.int64(542),
#  '90': np.int64(17),
#  'want': np.int64(2895),
#  'color': np.int64(476),
#  'depth': np.int64(681),
#  'ingeni': np.int64(1361),
#  'abl': np.int64(21),
#  'hit': np.int64(1244),
#  '100': np.int64(1),
#  'troubl': np.int64(2759),
#  'day': np.int64(634),
#  'note': np.int64(1784),
#  'sciencefict': np.int64(2260),
#  'narr': np.int64(1743),
#  'style': np.int64(2558),
#  'frustrat': np.int64(1074),
#  'difficult': np.int64(705),
#  'unpredict': np.int64(2826),
#  'scream': np.int64(2269),
#  'ii': np.int64(1302),
#  'achiev': np.int64(37),
#  'ultim': np.int64(2774),
#  'insignific': np.int64(1374),
#  'scifi': np.int64(2262),
#  'spectacl': np.int64(2462),
#  'epic': np.int64(871),
#  'fan': np.int64(963),
#  'hardli': np.int64(1192),
#  'ask': np.int64(159),
#  'plod': np.int64(1946),
#  'drama': np.int64(761),
#  'reach': np.int64(2085),
#  'translat': np.int64(2735),
#  'speak': np.int64(2457),
#  'forc': np.int64(1043),
#  'ponder': np.int64(1968),
#  'space': np.int64(2452),
#  'larg': np.int64(1495),
#  'consider': np.int64(530),
#  'aplomb': np.int64(130),
#  'cobbl': np.int64(467),
#  'flat': np.int64(1022),
#  'inan': np.int64(1328),
#  'aw': np.int64(189),
#  'told': np.int64(2709),
#  'scatter': np.int64(2251),
#  'chanc': np.int64(391),
#  'bold': np.int64(278),
#  'studio': np.int64(2553),
#  'actual': np.int64(44),
#  'thing': np.int64(2684),
#  'fear': np.int64(982),
#  'mess': np.int64(1660),
#  'infus': np.int64(1360),
#  'path': np.int64(1883),
#  'flash': np.int64(1019),
#  'warmth': np.int64(2899),
#  'gentl': np.int64(1103),
#  'humor': np.int64(1280),
#  'sensit': np.int64(2302),
#  'script': np.int64(2273),
#  'avoid': np.int64(188),
#  'pitfal': np.int64(1932),
#  'expect': np.int64(921),
#  'potenti': np.int64(1983),
#  'setup': np.int64(2316),
#  'load': np.int64(1553),
#  'credit': np.int64(590),
#  'girl': np.int64(1113),
#  'bar': np.int64(211),
#  'enjoy': np.int64(856),
#  'add': np.int64(48),
#  'dark': np.int64(624),
#  'vision': np.int64(2876),
#  'predecessor': np.int64(1992),
#  'ye': np.int64(2989),
#  'pace': np.int64(1849),
#  'unpleas': np.int64(2825),
#  'affair': np.int64(63),
#  'incred': np.int64(1342),
#  'anticip': np.int64(124),
#  'predict': np.int64(1993),
#  'brilliant': np.int64(308),
#  'profession': np.int64(2023),
#  'unassum': np.int64(2778),
#  'technic': np.int64(2649),
#  'posit': np.int64(1978),
#  'chang': np.int64(392),
#  'tone': np.int64(2713),
#  'beat': np.int64(225),
#  'innov': np.int64(1368),
#  'dim': np.int64(708),
#  'goofi': np.int64(1130),
#  'teem': np.int64(2654),
#  'kid': np.int64(1463),
#  'insid': np.int64(1372),
#  'laughabl': np.int64(1504),
#  'watchabl': np.int64(2906),
#  'valu': np.int64(2848),
#  'term': np.int64(2665),
#  'dentist': np.int64(675),
#  'honest': np.int64(1257),
#  'amazingli': np.int64(97),
#  'lame': np.int64(1488),
#  'straightforward': np.int64(2531),
#  'disappointingli': np.int64(719),
#  'slice': np.int64(2393),
#  'gem': np.int64(1099),
#  'delight': np.int64(664),
#  'spare': np.int64(2454),
#  'photographi': np.int64(1916),
#  'understand': np.int64(2795),
#  'plain': np.int64(1936),
#  'structur': np.int64(2548),
#  'frida': np.int64(1068),
#  'adventur': np.int64(61),
#  'indian': np.int64(1346),
#  'market': np.int64(1616),
#  'worth': np.int64(2975),
#  'price': np.int64(2006),
#  'gori': np.int64(1133),
#  'mayhem': np.int64(1633),
#  'produc': np.int64(2020),
#  'jerri': np.int64(1434),
#  'bruckheim': np.int64(325),
#  'joel': np.int64(1438),
#  'reflect': np.int64(2118),
#  'shallow': np.int64(2325),
#  'motiv': np.int64(1718),
#  'demograph': np.int64(669),
#  'target': np.int64(2640),
#  'pleas': np.int64(1940),
#  'blair': np.int64(255),
#  'witch': np.int64(2955),
#  'footag': np.int64(1042),
#  'second': np.int64(2281),
#  'folli': np.int64(1038),
#  'tediou': np.int64(2652),
#  'offer': np.int64(1812),
#  'oscar': np.int64(1830),
#  'nomin': np.int64(1774),
#  'esther': np.int64(885),
#  'unusu': np.int64(2834),
#  'stylish': np.int64(2559),
#  'exercis': np.int64(914),
#  'halfway': np.int64(1180),
#  'begin': np.int64(228),
#  'easi': np.int64(798),
#  'border': np.int64(284),
#  'thoroughli': np.int64(2686),
#  'grip': np.int64(1158),
#  'hard': np.int64(1191),
#  'distract': np.int64(741),
#  'fascin': np.int64(972),
#  'gun': np.int64(1172),
#  'cheat': np.int64(407),
#  'martial': np.int64(1619),
#  'comput': np.int64(507),
#  'camera': np.int64(351),
#  'breezi': np.int64(303),
#  'rhythm': np.int64(2175),
#  'sumptuou': np.int64(2592),
#  'stream': np.int64(2535),
#  'slick': np.int64(2394),
#  'manufactur': np.int64(1613),
#  'claim': np.int64(440),
#  'street': np.int64(2536),
#  'credibl': np.int64(589),
#  'nice': np.int64(1760),
#  'valuabl': np.int64(2849),
#  'messag': np.int64(1661),
#  'thank': np.int64(2678),
#  'guy': np.int64(1174),
#  'desper': np.int64(688),
#  'tarantino': np.int64(2639),
#  'grow': np.int64(1165),
#  'essenti': np.int64(883),
#  'collect': np.int64(473),
#  'bit': np.int64(248),
#  'rest': np.int64(2162),
#  'elev': np.int64(822),
#  'hugh': np.int64(1277),
#  'grant': np.int64(1142),
#  'line': np.int64(1543),
#  'arriv': np.int64(148),
#  'earli': np.int64(793),
#  'stay': np.int64(2505),
#  'genuin': np.int64(1105),
#  'insight': np.int64(1373),
#  'urban': np.int64(2839),
#  'hour': np.int64(1272),
#  'john': np.int64(1439),
#  'blue': np.int64(272),
#  'green': np.int64(1152),
#  'brown': np.int64(323),
#  'organ': np.int64(1828),
#  'crime': np.int64(594),
#  'includ': np.int64(1333),
#  'lane': np.int64(1491),
#  'richard': np.int64(2177),
#  'ludicr': np.int64(1582),
#  'skill': np.int64(2381),
#  'steven': np.int64(2510),
#  'seagal': np.int64(2276),
#  'warm': np.int64(2898),
#  'water': np.int64(2907),
#  'red': np.int64(2109),
#  'bridg': np.int64(304),
#  'celebr': np.int64(378),
#  'energi': np.int64(851),
#  'heal': np.int64(1205),
#  'sensat': np.int64(2300),
#  'reallif': np.int64(2094),
#  'metaphor': np.int64(1663),
#  'home': np.int64(1256),
#  'leav': np.int64(1515),
#  'mention': np.int64(1656),
#  'retain': np.int64(2164),
#  'ambigu': np.int64(98),
#  'ad': np.int64(45),
#  'reson': np.int64(2158),
#  'format': np.int64(1051),
#  'oldfashion': np.int64(1816),
#  'educ': np.int64(810),
#  'viewer': np.int64(2868),
#  'word': np.int64(2969),
#  'handsom': np.int64(1188),
#  'unfulfil': np.int64(2810),
#  'charmless': np.int64(403),
#  'haunt': np.int64(1202),
#  'debut': np.int64(642),
#  'fine': np.int64(1004),
#  'aim': np.int64(75),
#  'mainli': np.int64(1598),
#  'plenti': np.int64(1944),
#  'grownup': np.int64(1166),
#  'seat': np.int64(2280),
#  'everyth': np.int64(895),
#  'observ': np.int64(1800),
#  'secondhand': np.int64(2282),
#  'familiar': np.int64(961),
#  'spot': np.int64(2487),
#  'player': np.int64(1939),
#  'gift': np.int64(1112),
#  'contribut': np.int64(548),
#  'choppi': np.int64(427),
#  'school': np.int64(2257),
#  'sex': np.int64(2319),
#  'demand': np.int64(667),
#  'receiv': np.int64(2098),
#  'excel': np.int64(908),
#  'blast': np.int64(259),
#  'adrenalin': np.int64(58),
#  'escap': np.int64(880),
#  'kick': np.int64(1462),
#  'cultur': np.int64(607),
#  'horrifi': np.int64(1267),
#  'mourn': np.int64(1721),
#  'tragedi': np.int64(2730),
#  'privat': np.int64(2012),
#  'gain': np.int64(1088),
#  'momentum': np.int64(1699),
#  'sand': np.int64(2232),
#  'pale': np.int64(1858),
#  'characterist': np.int64(397),
#  'jaglom': np.int64(1425),
#  'honestli': np.int64(1259),
#  'affect': np.int64(64),
#  'sorvino': np.int64(2444),
#  'limit': np.int64(1541),
#  'success': np.int64(2578),
#  'level': np.int64(1528),
#  'miser': np.int64(1684),
#  'accomplish': np.int64(32),
#  'approach': np.int64(137),
#  'irish': np.int64(1412),
#  'exhilar': np.int64(915),
#  'bound': np.int64(289),
#  'appeal': np.int64(133),
#  'trashi': np.int64(2740),
#  'trash': np.int64(2739),
#  'right': np.int64(2182),
#  'summer': np.int64(2591),
#  'sustain': np.int64(2616),
#  'endear': np.int64(844),
#  'howev': np.int64(1275),
#  'especi': np.int64(881),
#  'ambiti': np.int64(100),
#  'sister': np.int64(2374),
#  'subject': np.int64(2563),
#  'matter': np.int64(1629),
#  'incompet': np.int64(1335),
#  'alway': np.int64(94),
#  'droll': np.int64(773),
#  'whimsi': np.int64(2933),
#  'overcom': np.int64(1839),
#  'parker': np.int64(1872),
#  'creativ': np.int64(587),
#  'root': np.int64(2204),
#  'fate': np.int64(978),
#  'casual': np.int64(372),
#  'ode': np.int64(1808),
#  'walk': np.int64(2888),
#  'horribl': np.int64(1266),
#  'terribl': np.int64(2667),
#  'stage': np.int64(2493),
#  'screen': np.int64(2270),
#  'ellen': np.int64(824),
#  'pompeo': np.int64(1967),
#  'giant': np.int64(1110),
#  'copi': np.int64(562),
#  'excit': np.int64(910),
#  'interview': np.int64(1398),
#  'evoc': np.int64(898),
#  'decad': np.int64(643),
#  'ago': np.int64(71),
#  'fail': np.int64(949),
#  'caught': np.int64(375),
#  'compani': np.int64(491),
#  'astonish': np.int64(168),
#  'growth': np.int64(1167),
#  'frozen': np.int64(1073),
#  'soap': np.int64(2416),
#  'opera': np.int64(1822),
#  'simpli': np.int64(2364),
#  'free': np.int64(1063),
#  'tv': np.int64(2768),
#  'giddi': np.int64(1111),
#  'choos': np.int64(425),
#  'open': np.int64(1820),
#  'wound': np.int64(2978),
#  'suffer': np.int64(2584),
#  'failur': np.int64(950),
#  'hoffman': np.int64(1245),
#  'clinic': np.int64(455),
#  'wonder': np.int64(2963),
#  'cinematographi': np.int64(437),
#  'highconcept': np.int64(1231),
#  'vulgar': np.int64(2884),
#  'refus': np.int64(2122),
#  'reason': np.int64(2095),
#  'confus': np.int64(523),
#  'need': np.int64(1753),
#  'surreal': np.int64(2609),
#  'passion': np.int64(1880),
#  'materi': np.int64(1627),
#  'formula': np.int64(1052),
#  'wrong': np.int64(2986),
#  'wellcraft': np.int64(2923),
#  'distanc': np.int64(736),
#  'render': np.int64(2143),
#  'cheesi': np.int64(411),
#  'sinc': np.int64(2368),
#  'awe': np.int64(194),
#  'joyou': np.int64(1448),
#  'romp': np.int64(2202),
#  'nonstop': np.int64(1779),
#  'hoot': np.int64(1263),
#  'sabotag': np.int64(2217),
#  'tortur': np.int64(2720),
#  'argentin': np.int64(142),
#  'remind': np.int64(2140),
#  'feelgood': np.int64(990),
#  'spoof': np.int64(2484),
#  'aspect': np.int64(160),
#  'white': np.int64(2936),
#  'packag': np.int64(1851),
#  'wrap': np.int64(2980),
#  'crass': np.int64(582),
#  'frame': np.int64(1057),
#  'vulner': np.int64(2885),
#  'persona': np.int64(1906),
#  'plight': np.int64(1945),
#  'flamboy': np.int64(1018),
#  'femal': np.int64(992),
#  'squar': np.int64(2490),
#  'cabl': np.int64(344),
#  'channel': np.int64(393),
#  'appal': np.int64(131),
#  'amaz': np.int64(96),
#  'spiderman': np.int64(2472),
#  'stomachturn': np.int64(2522),
#  'violenc': np.int64(2872),
#  'undeni': np.int64(2788),
#  'mr': np.int64(1727),
#  'broomfield': np.int64(320),
#  'continu': np.int64(545),
#  'lesser': np.int64(1525),
#  'thriller': np.int64(2691),
#  'joke': np.int64(1440),
#  'wallac': np.int64(2889),
#  'complex': np.int64(501),
#  'wooden': np.int64(2967),
#  'lowkey': np.int64(1580),
#  'manner': np.int64(1612),
#  'burn': np.int64(339),
#  'strongest': np.int64(2546),
#  'brother': np.int64(321),
#  'miss': np.int64(1689),
#  'outstand': np.int64(1834),
#  'potent': np.int64(1982),
#  'write': np.int64(2982),
#  'seek': np.int64(2285),
#  'insult': np.int64(1384),
#  'fat': np.int64(976),
#  'greek': np.int64(1151),
#  'wed': np.int64(2915),
#  'popular': np.int64(1975),
#  'focu': np.int64(1035),
#  'biopic': np.int64(246),
#  'document': np.int64(746),
#  'male': np.int64(1605),
#  'era': np.int64(877),
#  'signpost': np.int64(2357),
#  'mark': np.int64(1615),
#  'slow': np.int64(2401),
#  'linger': np.int64(1544),
#  'quirk': np.int64(2065),
#  'seriou': np.int64(2310),
#  'irrelev': np.int64(1415),
#  'gradual': np.int64(1139),
#  'describ': np.int64(683),
#  'korean': np.int64(1481),
#  '2002': np.int64(8),
#  'solid': np.int64(2424),
#  'assur': np.int64(167),
#  'modern': np.int64(1694),
#  'ironi': np.int64(1414),
#  'road': np.int64(2189),
#  'themat': np.int64(2681),
#  'obviou': np.int64(1802),
#  'sexual': np.int64(2321),
#  'polit': np.int64(1965),
#  'smug': np.int64(2411),
#  'captur': np.int64(360),
#  'deserv': np.int64(684),
#  'pass': np.int64(1878),
#  'stupid': np.int64(2557),
#  'element': np.int64(821),
#  'mood': np.int64(1707),
#  'combin': np.int64(477),
#  'malais': np.int64(1604),
#  'felt': np.int64(991),
#  'weird': np.int64(2919),
#  'offens': np.int64(1811),
#  'santa': np.int64(2236),
#  'children': np.int64(417),
#  'intim': np.int64(1399),
#  'wish': np.int64(2953),
#  'loos': np.int64(1564),
#  'lazi': np.int64(1509),
#  'crackl': np.int64(578),
#  'fairli': np.int64(953),
#  'studi': np.int64(2552),
#  'main': np.int64(1597),
#  'genial': np.int64(1101),
#  'job': np.int64(1437),
#  'husband': np.int64(1287),
#  'thrown': np.int64(2693),
#  'book': np.int64(283),
#  'nonsens': np.int64(1778),
#  'darker': np.int64(625),
#  'misogyni': np.int64(1688),
#  'suffoc': np.int64(2585),
#  'illumin': np.int64(1305),
#  'daughter': np.int64(629),
#  'chill': np.int64(418),
#  'heartwarm': np.int64(1211),
#  'retread': np.int64(2165),
#  'reef': np.int64(2114),
#  'surviv': np.int64(2612),
#  'break': np.int64(298),
#  'deep': np.int64(650),
#  'unsettl': np.int64(2830),
#  'spooki': np.int64(2485),
#  'supernatur': np.int64(2598),
#  'grand': np.int64(1140),
#  'goodnatur': np.int64(1129),
#  'audienc': np.int64(183),
#  'nuanc': np.int64(1793),
#  'lead': np.int64(1510),
#  'star': np.int64(2497),
#  'selfindulg': np.int64(2295),
#  'idiot': np.int64(1300),
#  'mental': np.int64(1655),
#  'punk': np.int64(2051),
#  'medium': np.int64(1645),
#  'percept': np.int64(1898),
#  'hole': np.int64(1248),
#  'pilot': np.int64(1928),
#  'team': np.int64(2646),
#  'blend': np.int64(263),
#  'chabrol': np.int64(388),
#  'master': np.int64(1624),
#  'innuendo': np.int64(1369),
#  'rivet': np.int64(2188),
#  'war': np.int64(2896),
#  ...}

# %%
# Calculate statistical similarity
sim_5_100_bow = cosine_similarity(train_bow_stem[4].toarray()[0],
                             train_bow_stem[99].toarray()[0])
sim_5_15000_bow = cosine_similarity(train_bow_stem[4].toarray()[0],
                               train_bow_stem[14999].toarray()[0])
sim_5_50000_bow = cosine_similarity(train_bow_stem[4].toarray()[0],
                               train_bow_stem[49999].toarray()[0])

# %%
print(f"{stem_train[4]} \n {sim_5_100_bow} \n {stem_train[99]}")
# Out:
# worst revengeofthenerd cliché filmmak could dredg
#  0.0
#  act direct clear washington certainli new career ahead

# %%
print(f"{stem_train[4]} \n {sim_5_15000_bow} \n {stem_train[14999]}")
# Out:
# worst revengeofthenerd cliché filmmak could dredg
#  0.0
#  eloqu

# %%
print(f"{stem_train[4]} \n {sim_5_50000_bow} \n {stem_train[49999]}")
# Out:
# worst revengeofthenerd cliché filmmak could dredg
#  0.0
#  stylish

# %% [markdown]
# ## ✅ 9. TF-IDF & Similarity
#
# *Statistical Similarity*

# %%
# Create vectorizer (handles all preprocessing)
tfidf_vectorizer = TfidfVectorizer(analyzer = "word",
                             lowercase=True,
                             stop_words="english",
                             max_features=3000)

# %% [markdown]
# **lemmatised sentences**

# %%
# Calculate TF-IDF - lemmatised sentences
train_tfidf_lemma = tfidf_vectorizer.fit_transform(lemma_train) # Learn vocabulary from training
val_tfidf_lemma = tfidf_vectorizer.transform(lemma_val) # Apply to validation

# %%
# Get vocabulary and tokens after fitting
vocabulary_tfidf = tfidf_vectorizer.vocabulary_
tokens_tfidf = tfidf_vectorizer.get_feature_names_out()

# %%
vocabulary_tfidf
# Out:
# {'hide': np.int64(1230),
#  'new': np.int64(1753),
#  'contain': np.int64(530),
#  'wit': np.int64(2954),
#  'labor': np.int64(1487),
#  'gag': np.int64(1089),
#  'love': np.int64(1572),
#  'character': np.int64(379),
#  'communicate': np.int64(482),
#  'beautiful': np.int64(217),
#  'human': np.int64(1283),
#  'nature': np.int64(1743),
#  'remain': np.int64(2151),
#  'utterly': np.int64(2846),
#  'satisfy': np.int64(2255),
#  'worst': np.int64(2976),
#  'clichés': np.int64(442),
#  'filmmakers': np.int64(1003),
#  'far': np.int64(968),
#  'tragic': np.int64(2732),
#  'merit': np.int64(1658),
#  'superficial': np.int64(2595),
#  'treatment': np.int64(2745),
#  'demonstrate': np.int64(661),
#  'director': np.int64(703),
#  'hollywood': np.int64(1255),
#  'game': np.int64(1091),
#  'turn': np.int64(2766),
#  'small': np.int64(2418),
#  'personal': np.int64(1902),
#  'film': np.int64(1001),
#  'emotional': np.int64(818),
#  'wallop': np.int64(2895),
#  'depress': np.int64(668),
#  'poetry': np.int64(1951),
#  'deeply': np.int64(642),
#  'think': np.int64(2685),
#  'absurd': np.int64(21),
#  'moviegoers': np.int64(1714),
#  'nt': np.int64(1782),
#  'make': np.int64(1598),
#  'movies': np.int64(1717),
#  'like': np.int64(1540),
#  'use': np.int64(2841),
#  'happen': np.int64(1193),
#  'saw': np.int64(2261),
#  'bad': np.int64(194),
#  'movie': np.int64(1713),
#  'lend': np.int64(1521),
#  'dignity': np.int64(696),
#  'dumb': np.int64(771),
#  'story': np.int64(2533),
#  'greatest': np.int64(1154),
#  'musicians': np.int64(1728),
#  'cold': np.int64(459),
#  'usual': np.int64(2843),
#  'intelligence': np.int64(1397),
#  'subtlety': np.int64(2575),
#  'redundant': np.int64(2126),
#  'concept': np.int64(503),
#  'swim': np.int64(2622),
#  'young': np.int64(2995),
#  'woman': np.int64(2962),
#  'face': np.int64(946),
#  'cast': np.int64(356),
#  'actress': np.int64(44),
#  'project': np.int64(2038),
#  'doubt': np.int64(742),
#  'succeed': np.int64(2578),
#  'equal': np.int64(865),
#  'original': np.int64(1823),
#  'ways': np.int64(2911),
#  'better': np.int64(233),
#  'black': np.int64(247),
#  'camp': np.int64(338),
#  'conspiracy': np.int64(525),
#  'dirty': np.int64(707),
#  'smile': np.int64(2423),
#  'come': np.int64(467),
#  'performances': np.int64(1896),
#  'unfunny': np.int64(2810),
#  'mix': np.int64(1685),
#  'antic': np.int64(115),
#  'spirit': np.int64(2482),
#  'half': np.int64(1183),
#  'dragonfly': np.int64(749),
#  'worse': np.int64(2975),
#  'world': np.int64(2973),
#  'cinema': np.int64(419),
#  'good': np.int64(1131),
#  'view': np.int64(2867),
#  'alternative': np.int64(86),
#  'plot': np.int64(1946),
#  'start': np.int64(2505),
#  'finish': np.int64(1012),
#  'action': np.int64(40),
#  'stilted': np.int64(2521),
#  'cylinders': np.int64(605),
#  'little': np.int64(1552),
#  'preachy': np.int64(1994),
#  'poorly': np.int64(1969),
#  'act': np.int64(39),
#  'year': np.int64(2989),
#  'sit': np.int64(2389),
#  'best': np.int64(232),
#  'man': np.int64(1602),
#  'weave': np.int64(2914),
#  'theme': np.int64(2682),
#  'funny': np.int64(1084),
#  'issue': np.int64(1427),
#  'adults': np.int64(57),
#  'marriage': np.int64(1613),
#  'real': np.int64(2101),
#  'silly': np.int64(2373),
#  'crude': np.int64(590),
#  'storyline': np.int64(2534),
#  'heroes': np.int64(1225),
#  'existence': np.int64(914),
#  'entire': np.int64(859),
#  'point': np.int64(1954),
#  'dog': np.int64(739),
#  'course': np.int64(561),
#  'classic': np.int64(428),
#  'sense': np.int64(2313),
#  'dry': np.int64(766),
#  'recycle': np.int64(2121),
#  'time': np.int64(2701),
#  'care': np.int64(347),
#  'count': np.int64(557),
#  'cover': np.int64(562),
#  'territory': np.int64(2670),
#  'originality': np.int64(1824),
#  'suggest': np.int64(2587),
#  'feature': np.int64(986),
#  'million': np.int64(1672),
#  'version': np.int64(2860),
#  'gorgeous': np.int64(1135),
#  'deceptively': np.int64(637),
#  'minimalist': np.int64(1676),
#  'cross': np.int64(587),
#  'prove': np.int64(2046),
#  'lose': np.int64(1566),
#  'touch': np.int64(2721),
#  'bring': np.int64(300),
#  'superb': np.int64(2594),
#  'performance': np.int64(1895),
#  'middle': np.int64(1664),
#  'muddle': np.int64(1720),
#  'splash': np.int64(2485),
#  'bloody': np.int64(261),
#  'beauty': np.int64(219),
#  'vivid': np.int64(2885),
#  'scorsese': np.int64(2280),
#  'pointless': np.int64(1955),
#  'beautifully': np.int64(218),
#  'contrive': np.int64(539),
#  'situations': np.int64(2392),
#  'poor': np.int64(1968),
#  'drive': np.int64(760),
#  'subtle': np.int64(2573),
#  'son': np.int64(2443),
#  'room': np.int64(2221),
#  'sophisticate': np.int64(2447),
#  'rich': np.int64(2195),
#  'vein': np.int64(2857),
#  'stuff': np.int64(2557),
#  'apparent': np.int64(121),
#  'joy': np.int64(1451),
#  'shoot': np.int64(2357),
#  'ugly': np.int64(2772),
#  'digital': np.int64(695),
#  'video': np.int64(2865),
#  'sour': np.int64(2459),
#  'core': np.int64(551),
#  'exploration': np.int64(928),
#  'emptiness': np.int64(827),
#  'end': np.int64(831),
#  'hold': np.int64(1250),
#  'thrill': np.int64(2691),
#  'pretty': np.int64(2011),
#  'damn': np.int64(610),
#  'feel': np.int64(989),
#  'lousy': np.int64(1571),
#  'record': np.int64(2119),
#  'industry': np.int64(1359),
#  'current': np.int64(600),
#  'magnificent': np.int64(1592),
#  'swoop': np.int64(2624),
#  'shots': np.int64(2359),
#  'breathtaking': np.int64(290),
#  'overall': np.int64(1830),
#  'experience': np.int64(923),
#  'sound': np.int64(2457),
#  'cruel': np.int64(592),
#  'carry': np.int64(351),
#  'men': np.int64(1651),
#  'marginal': np.int64(1610),
#  'ideas': np.int64(1301),
#  'women': np.int64(2963),
#  'total': np.int64(2719),
#  'lack': np.int64(1488),
#  'empathy': np.int64(821),
#  'fresh': np.int64(1069),
#  'history': np.int64(1246),
#  'eastwood': np.int64(787),
#  'pay': np.int64(1884),
#  'earnest': np.int64(780),
#  'homage': np.int64(1258),
#  'weak': np.int64(2912),
#  'skip': np.int64(2397),
#  'laugh': np.int64(1505),
#  'surprise': np.int64(2605),
#  'affirm': np.int64(64),
#  'power': np.int64(1988),
#  'help': np.int64(1222),
#  'people': np.int64(1889),
#  'endure': np.int64(836),
#  'unimaginable': np.int64(2811),
#  'horror': np.int64(1274),
#  'absolute': np.int64(17),
#  'generate': np.int64(1103),
#  'life': np.int64(1531),
#  'fun': np.int64(1081),
#  'low': np.int64(1575),
#  'base': np.int64(210),
#  'true': np.int64(2757),
#  'historically': np.int64(1245),
#  'significant': np.int64(2370),
#  'tribute': np.int64(2749),
#  'actors': np.int64(43),
#  'throw': np.int64(2694),
#  'spark': np.int64(2465),
#  'appear': np.int64(124),
#  'ca': np.int64(330),
#  'heat': np.int64(1215),
#  'comedy': np.int64(471),
#  'robert': np.int64(2208),
#  'deniro': np.int64(663),
#  'manage': np.int64(1603),
#  'terrific': np.int64(2668),
#  'flair': np.int64(1022),
#  'farce': np.int64(969),
#  'family': np.int64(961),
#  'intensity': np.int64(1402),
#  'fashion': np.int64(973),
#  'engross': np.int64(842),
#  'entertainment': np.int64(855),
#  'animate': np.int64(110),
#  'write': np.int64(2982),
#  'believe': np.int64(225),
#  'central': np.int64(367),
#  'creation': np.int64(572),
#  'comic': np.int64(475),
#  'parody': np.int64(1867),
#  'melodrama': np.int64(1645),
#  'toss': np.int64(2718),
#  'intrigue': np.int64(1413),
#  'question': np.int64(2072),
#  'difference': np.int64(692),
#  'moments': np.int64(1690),
#  'generous': np.int64(1106),
#  'subversive': np.int64(2577),
#  'follow': np.int64(1040),
#  'stale': np.int64(2500),
#  'standard': np.int64(2502),
#  'explore': np.int64(929),
#  'underbelly': np.int64(2790),
#  'criminal': np.int64(583),
#  'overbear': np.int64(1831),
#  'overthetop': np.int64(1837),
#  'duvall': np.int64(773),
#  'sudden': np.int64(2583),
#  'direct': np.int64(700),
#  'clear': np.int64(432),
#  'washington': np.int64(2904),
#  'certainly': np.int64(371),
#  'career': np.int64(348),
#  'ahead': np.int64(70),
#  'memory': np.int64(1650),
#  'respectable': np.int64(2178),
#  'grate': np.int64(1149),
#  'hate': np.int64(1204),
#  'tear': np.int64(2645),
#  'eye': np.int64(944),
#  'away': np.int64(186),
#  'image': np.int64(1310),
#  'long': np.int64(1561),
#  'read': np.int64(2100),
#  'subtitle': np.int64(2572),
#  'addition': np.int64(51),
#  'sport': np.int64(2492),
#  'title': np.int64(2707),
#  'recent': np.int64(2113),
#  'cinematic': np.int64(420),
#  'generally': np.int64(1102),
#  'quite': np.int64(2079),
#  'build': np.int64(319),
#  'theater': np.int64(2677),
#  'late': np.int64(1502),
#  'mystery': np.int64(1731),
#  'science': np.int64(2274),
#  'killer': np.int64(1472),
#  'website': np.int64(2916),
#  'work': np.int64(2972),
#  'concert': np.int64(505),
#  'direction': np.int64(701),
#  'fluid': np.int64(1036),
#  'nononsense': np.int64(1770),
#  'authority': np.int64(180),
#  'seal': np.int64(2292),
#  'deal': np.int64(629),
#  'step': np.int64(2514),
#  'harsh': np.int64(1200),
#  'piece': np.int64(1923),
#  'storytelling': np.int64(2535),
#  'attractive': np.int64(175),
#  'talented': np.int64(2631),
#  'landscape': np.int64(1493),
#  'create': np.int64(571),
#  'wickedly': np.int64(2939),
#  'watch': np.int64(2906),
#  'provide': np.int64(2047),
#  'pleasures': np.int64(1942),
#  'altogether': np.int64(87),
#  'slight': np.int64(2406),
#  'kind': np.int64(1473),
#  'masterpiece': np.int64(1625),
#  'maybe': np.int64(1631),
#  'twice': np.int64(2768),
#  'completely': np.int64(492),
#  'forget': np.int64(1047),
#  'car': np.int64(346),
#  'park': np.int64(1865),
#  'lot': np.int64(1569),
#  'charm': np.int64(385),
#  'quirky': np.int64(2078),
#  'match': np.int64(1626),
#  'pure': np.int64(2062),
#  'old': np.int64(1809),
#  'college': np.int64(462),
#  'try': np.int64(2762),
#  'wellwritten': np.int64(2930),
#  'wellacted': np.int64(2926),
#  'answer': np.int64(113),
#  'clumsy': np.int64(455),
#  'dialogue': np.int64(689),
#  'heavyhanded': np.int64(1218),
#  'sentiment': np.int64(2319),
#  'lovely': np.int64(1573),
#  'trifle': np.int64(2751),
#  'unfortunately': np.int64(2808),
#  'cuteness': np.int64(604),
#  'budget': np.int64(317),
#  'surprisingly': np.int64(2606),
#  'shoddy': np.int64(2356),
#  'proper': np.int64(2040),
#  'conviction': np.int64(546),
#  'role': np.int64(2213),
#  'jason': np.int64(1438),
#  'bourne': np.int64(279),
#  'great': np.int64(1152),
#  'poignant': np.int64(1953),
#  'artist': np.int64(144),
#  'years': np.int64(2991),
#  'effort': np.int64(799),
#  'share': np.int64(2347),
#  'impressions': np.int64(1330),
#  'loss': np.int64(1568),
#  'art': np.int64(138),
#  'supremely': np.int64(2599),
#  'lively': np.int64(1554),
#  'engage': np.int64(840),
#  'examination': np.int64(895),
#  'similar': np.int64(2374),
#  'irritate': np.int64(1426),
#  'collapse': np.int64(460),
#  'challenge': np.int64(373),
#  'forgive': np.int64(1049),
#  'flaw': np.int64(1028),
#  'serve': np.int64(2328),
#  'learn': np.int64(1516),
#  'tool': np.int64(2714),
#  'way': np.int64(2910),
#  'big': np.int64(235),
#  'excuse': np.int64(908),
#  'play': np.int64(1935),
#  'scene': np.int64(2268),
#  'effective': np.int64(797),
#  'stick': np.int64(2519),
#  'tradition': np.int64(2726),
#  'familial': np.int64(958),
#  'community': np.int64(483),
#  'deliver': np.int64(656),
#  'promise': np.int64(2039),
#  'look': np.int64(1563),
#  'wild': np.int64(2942),
#  'ride': np.int64(2199),
#  'set': np.int64(2330),
#  'cell': np.int64(364),
#  'phone': np.int64(1911),
#  'sketchy': np.int64(2394),
#  'business': np.int64(327),
#  'suppose': np.int64(2598),
#  'absolutely': np.int64(18),
#  'ridiculous': np.int64(2200),
#  'tasteful': np.int64(2640),
#  'rock': np.int64(2210),
#  'roll': np.int64(2215),
#  'suspense': np.int64(2613),
#  'realistic': np.int64(2103),
#  'portrayal': np.int64(1976),
#  'grab': np.int64(1139),
#  'lump': np.int64(1581),
#  'squeeze': np.int64(2497),
#  'stunt': np.int64(2559),
#  'reveal': np.int64(2185),
#  'important': np.int64(1326),
#  'special': np.int64(2469),
#  'talents': np.int64(2632),
#  'service': np.int64(2329),
#  'welcome': np.int64(2925),
#  'relief': np.int64(2149),
#  'filmmaking': np.int64(1004),
#  'easily': np.int64(786),
#  'wait': np.int64(2890),
#  'justify': np.int64(1461),
#  'theatrical': np.int64(2679),
#  'death': np.int64(630),
#  'extraordinary': np.int64(941),
#  'faith': np.int64(953),
#  'heart': np.int64(1210),
#  'adaptation': np.int64(49),
#  'sure': np.int64(2600),
#  'salton': np.int64(2245),
#  'sea': np.int64(2290),
#  'noir': np.int64(1765),
#  'tight': np.int64(2700),
#  'nasty': np.int64(1738),
#  'overlong': np.int64(1835),
#  'bombastic': np.int64(270),
#  'derivative': np.int64(670),
#  'audacious': np.int64(176),
#  'outrageous': np.int64(1826),
#  'disney': np.int64(721),
#  'sequel': np.int64(2323),
#  'final': np.int64(1005),
#  'suck': np.int64(2582),
#  'despite': np.int64(679),
#  'eat': np.int64(789),
#  'argue': np.int64(133),
#  'fight': np.int64(999),
#  'problem': np.int64(2022),
#  'ambition': np.int64(92),
#  'compel': np.int64(488),
#  'picture': np.int64(1920),
#  'run': np.int64(2228),
#  'mere': np.int64(1656),
#  'minutes': np.int64(1678),
#  'remarkable': np.int64(2153),
#  'procession': np.int64(2027),
#  'sweep': np.int64(2618),
#  'romance': np.int64(2218),
#  'genre': np.int64(1108),
#  'date': np.int64(618),
#  'imax': np.int64(1315),
#  'short': np.int64(2358),
#  'pleasant': np.int64(1938),
#  'ooze': np.int64(1814),
#  'involve': np.int64(1419),
#  'save': np.int64(2258),
#  'dash': np.int64(617),
#  'slightest': np.int64(2407),
#  'wildly': np.int64(2944),
#  'uneven': np.int64(2798),
#  'poke': np.int64(1956),
#  'provoke': np.int64(2049),
#  'spear': np.int64(2468),
#  'music': np.int64(1726),
#  'videos': np.int64(2866),
#  'content': np.int64(532),
#  '90': np.int64(12),
#  'want': np.int64(2898),
#  'color': np.int64(463),
#  'depth': np.int64(669),
#  'ingenious': np.int64(1367),
#  'able': np.int64(16),
#  'hit': np.int64(1247),
#  'trouble': np.int64(2756),
#  'day': np.int64(623),
#  'note': np.int64(1777),
#  'sciencefiction': np.int64(2275),
#  'narrative': np.int64(1734),
#  'style': np.int64(2561),
#  'frustrate': np.int64(1077),
#  'difficult': np.int64(694),
#  'unpredictable': np.int64(2826),
#  'scream': np.int64(2283),
#  'ii': np.int64(1307),
#  'achieve': np.int64(36),
#  'ultimate': np.int64(2773),
#  'scifi': np.int64(2276),
#  'spectacle': np.int64(2471),
#  'epic': np.int64(862),
#  'fan': np.int64(963),
#  'hardly': np.int64(1197),
#  'ask': np.int64(153),
#  'plod': np.int64(1945),
#  'dramas': np.int64(752),
#  'reach': np.int64(2098),
#  'translation': np.int64(2737),
#  'speak': np.int64(2467),
#  'force': np.int64(1044),
#  'ponder': np.int64(1965),
#  'space': np.int64(2462),
#  'large': np.int64(1497),
#  'considerable': np.int64(523),
#  'aplomb': np.int64(119),
#  'cobble': np.int64(456),
#  'largely': np.int64(1498),
#  'flat': np.int64(1026),
#  'inane': np.int64(1338),
#  'awful': np.int64(188),
#  'tell': np.int64(2658),
#  'scatter': np.int64(2266),
#  'chance': np.int64(375),
#  'bold': np.int64(269),
#  'studio': np.int64(2555),
#  'standards': np.int64(2503),
#  'actually': np.int64(47),
#  'effect': np.int64(796),
#  'thing': np.int64(2683),
#  'fear': np.int64(982),
#  'mess': np.int64(1660),
#  'infuse': np.int64(1366),
#  'path': np.int64(1877),
#  'flash': np.int64(1024),
#  'warmth': np.int64(2901),
#  'gentle': np.int64(1109),
#  'humor': np.int64(1286),
#  'sensitive': np.int64(2316),
#  'script': np.int64(2289),
#  'avoid': np.int64(183),
#  'pitfalls': np.int64(1929),
#  'expect': np.int64(919),
#  'potentially': np.int64(1985),
#  'setup': np.int64(2332),
#  'load': np.int64(1555),
#  'credit': np.int64(578),
#  'girl': np.int64(1119),
#  'bar': np.int64(205),
#  'enjoy': np.int64(844),
#  'add': np.int64(50),
#  'dark': np.int64(614),
#  'predecessors': np.int64(1998),
#  'yes': np.int64(2992),
#  'pace': np.int64(1842),
#  'extremely': np.int64(943),
#  'unpleasant': np.int64(2825),
#  'entirely': np.int64(860),
#  'performers': np.int64(1897),
#  'affair': np.int64(61),
#  'incredibly': np.int64(1353),
#  'things': np.int64(2684),
#  'predictable': np.int64(1999),
#  'brilliant': np.int64(297),
#  'entertain': np.int64(854),
#  'professional': np.int64(2033),
#  'unassuming': np.int64(2777),
#  'technically': np.int64(2647),
#  'positive': np.int64(1977),
#  'change': np.int64(376),
#  'tone': np.int64(2712),
#  'beat': np.int64(216),
#  'goofy': np.int64(1134),
#  'teem': np.int64(2651),
#  'kid': np.int64(1468),
#  'inside': np.int64(1378),
#  'laughable': np.int64(1506),
#  'watchable': np.int64(2907),
#  'length': np.int64(1522),
#  'value': np.int64(2849),
#  'respect': np.int64(2177),
#  'term': np.int64(2665),
#  'dentist': np.int64(664),
#  'honest': np.int64(1260),
#  'emotions': np.int64(820),
#  'amazingly': np.int64(90),
#  'lame': np.int64(1491),
#  'straightforward': np.int64(2537),
#  'disappointingly': np.int64(709),
#  'slice': np.int64(2404),
#  'gem': np.int64(1100),
#  'delightful': np.int64(654),
#  'spare': np.int64(2464),
#  'photography': np.int64(1914),
#  'understand': np.int64(2793),
#  'plain': np.int64(1933),
#  'structure': np.int64(2552),
#  'frida': np.int64(1071),
#  'different': np.int64(693),
#  'adventurous': np.int64(60),
#  'indian': np.int64(1355),
#  'market': np.int64(1612),
#  'worth': np.int64(2977),
#  'price': np.int64(2014),
#  'gory': np.int64(1137),
#  'mayhem': np.int64(1632),
#  'idea': np.int64(1297),
#  'produce': np.int64(2028),
#  'jerry': np.int64(1442),
#  'bruckheimer': np.int64(312),
#  'reflect': np.int64(2131),
#  'shallow': np.int64(2340),
#  'motivate': np.int64(1708),
#  'target': np.int64(2638),
#  'blair': np.int64(249),
#  'witch': np.int64(2955),
#  'footage': np.int64(1043),
#  'second': np.int64(2296),
#  'tedious': np.int64(2649),
#  'offer': np.int64(1807),
#  'oscar': np.int64(1825),
#  'nomination': np.int64(1767),
#  'esther': np.int64(878),
#  'unusual': np.int64(2833),
#  'stylish': np.int64(2562),
#  'exercise': np.int64(911),
#  'halfway': np.int64(1184),
#  'begin': np.int64(220),
#  'easy': np.int64(788),
#  'border': np.int64(274),
#  'thoroughly': np.int64(2686),
#  'grip': np.int64(1162),
#  'hard': np.int64(1196),
#  'fascinate': np.int64(972),
#  'gun': np.int64(1176),
#  'martial': np.int64(1615),
#  'arts': np.int64(149),
#  'computer': np.int64(500),
#  'camera': np.int64(337),
#  'breezy': np.int64(292),
#  'distract': np.int64(730),
#  'rhythms': np.int64(2194),
#  'sumptuous': np.int64(2591),
#  'stream': np.int64(2541),
#  'slick': np.int64(2405),
#  'manufacture': np.int64(1609),
#  'claim': np.int64(424),
#  'street': np.int64(2542),
#  'credibility': np.int64(576),
#  'nicely': np.int64(1757),
#  'perform': np.int64(1894),
#  'actresses': np.int64(45),
#  'valuable': np.int64(2848),
#  'message': np.int64(1661),
#  'thank': np.int64(2676),
#  'guy': np.int64(1178),
#  'desperately': np.int64(677),
#  'tarantino': np.int64(2637),
#  'grow': np.int64(1168),
#  'essentially': np.int64(876),
#  'collection': np.int64(461),
#  'bits': np.int64(243),
#  'rest': np.int64(2180),
#  'elevate': np.int64(809),
#  'hugh': np.int64(1282),
#  'grant': np.int64(1146),
#  'line': np.int64(1545),
#  'arrive': np.int64(137),
#  'early': np.int64(778),
#  'stay': np.int64(2512),
#  'genuine': np.int64(1111),
#  'insight': np.int64(1379),
#  'urban': np.int64(2839),
#  'hours': np.int64(1277),
#  'john': np.int64(1445),
#  'artful': np.int64(139),
#  'blue': np.int64(263),
#  'green': np.int64(1157),
#  'brown': np.int64(310),
#  'crime': np.int64(581),
#  'include': np.int64(1342),
#  'lane': np.int64(1494),
#  'richard': np.int64(2196),
#  'ludicrous': np.int64(1579),
#  'steven': np.int64(2518),
#  'seagal': np.int64(2291),
#  'warm': np.int64(2900),
#  'water': np.int64(2908),
#  'red': np.int64(2122),
#  'bridge': np.int64(293),
#  'celebration': np.int64(363),
#  'energy': np.int64(839),
#  'heal': np.int64(1208),
#  'sensational': np.int64(2312),
#  'reallife': np.int64(2106),
#  'metaphor': np.int64(1662),
#  'home': np.int64(1259),
#  'leave': np.int64(1517),
#  'mention': np.int64(1655),
#  'retain': np.int64(2182),
#  'resonance': np.int64(2174),
#  'format': np.int64(1051),
#  'oldfashioned': np.int64(1811),
#  'viewers': np.int64(2869),
#  'word': np.int64(2971),
#  'handsome': np.int64(1192),
#  'unfulfilling': np.int64(2809),
#  'drama': np.int64(751),
#  'charmless': np.int64(387),
#  'haunt': np.int64(1205),
#  'debut': np.int64(633),
#  'fine': np.int64(1008),
#  'aim': np.int64(72),
#  'mainly': np.int64(1594),
#  'plenty': np.int64(1943),
#  'grownups': np.int64(1170),
#  'seat': np.int64(2295),
#  'girls': np.int64(1120),
#  'observation': np.int64(1792),
#  'secondhand': np.int64(2297),
#  'familiar': np.int64(959),
#  'spot': np.int64(2493),
#  'players': np.int64(1936),
#  'gift': np.int64(1118),
#  'beings': np.int64(223),
#  'contribution': np.int64(537),
#  'choppy': np.int64(412),
#  'high': np.int64(1232),
#  'school': np.int64(2272),
#  'sex': np.int64(2335),
#  'demand': np.int64(658),
#  'receive': np.int64(2112),
#  'excellent': np.int64(900),
#  'blast': np.int64(254),
#  'escapism': np.int64(873),
#  'merely': np.int64(1657),
#  'kick': np.int64(1467),
#  'culture': np.int64(596),
#  'horrify': np.int64(1273),
#  'tragedies': np.int64(2730),
#  'private': np.int64(2019),
#  'scenes': np.int64(2270),
#  'gain': np.int64(1090),
#  'momentum': np.int64(1691),
#  'sand': np.int64(2246),
#  'pale': np.int64(1851),
#  'characteristic': np.int64(380),
#  'jaglom': np.int64(1433),
#  'honestly': np.int64(1261),
#  'affect': np.int64(62),
#  'sorvino': np.int64(2452),
#  'limitations': np.int64(1543),
#  'classical': np.int64(429),
#  'successful': np.int64(2580),
#  'level': np.int64(1527),
#  'intelligent': np.int64(1398),
#  'accomplish': np.int64(31),
#  'sequels': np.int64(2324),
#  'approach': np.int64(127),
#  'celebrate': np.int64(362),
#  'irish': np.int64(1421),
#  'exhilarate': np.int64(912),
#  'bind': np.int64(239),
#  'appeal': np.int64(123),
#  'trashy': np.int64(2741),
#  'trash': np.int64(2740),
#  'right': np.int64(2201),
#  'summer': np.int64(2590),
#  'sustain': np.int64(2615),
#  'endear': np.int64(832),
#  'days': np.int64(624),
#  'especially': np.int64(874),
#  'ambitious': np.int64(93),
#  'filmmaker': np.int64(1002),
#  'process': np.int64(2026),
#  'subject': np.int64(2566),
#  'matter': np.int64(1628),
#  'incompetent': np.int64(1345),
#  'conclusion': np.int64(507),
#  'wilde': np.int64(2943),
#  'droll': np.int64(761),
#  'whimsy': np.int64(2934),
#  'overcome': np.int64(1833),
#  'parker': np.int64(1866),
#  'creative': np.int64(573),
#  'root': np.int64(2222),
#  'fate': np.int64(978),
#  'casual': np.int64(357),
#  'ode': np.int64(1803),
#  'walk': np.int64(2892),
#  'horrible': np.int64(1271),
#  'terrible': np.int64(2666),
#  'stage': np.int64(2499),
#  'screen': np.int64(2284),
#  'ellen': np.int64(811),
#  'pompeo': np.int64(1964),
#  'giant': np.int64(1116),
#  'copy': np.int64(550),
#  'excite': np.int64(905),
#  'interview': np.int64(1407),
#  'evocative': np.int64(889),
#  'decades': np.int64(634),
#  'ago': np.int64(69),
#  'fail': np.int64(949),
#  'catch': np.int64(358),
#  'company': np.int64(484),
#  'astonish': np.int64(163),
#  'growth': np.int64(1171),
#  'freeze': np.int64(1065),
#  'soap': np.int64(2429),
#  'opera': np.int64(1818),
#  'simply': np.int64(2381),
#  'free': np.int64(1063),
#  'tv': np.int64(2767),
#  'giddy': np.int64(1117),
#  'choose': np.int64(410),
#  'purely': np.int64(2063),
#  'enjoyable': np.int64(845),
#  'open': np.int64(1816),
#  'suffer': np.int64(2584),
#  'failure': np.int64(950),
#  'hoffman': np.int64(1248),
#  'powerful': np.int64(1989),
#  'clinic': np.int64(444),
#  'wonderful': np.int64(2965),
#  'cinematography': np.int64(421),
#  'highconcept': np.int64(1233),
#  'refuse': np.int64(2136),
#  'reason': np.int64(2108),
#  'confuse': np.int64(515),
#  'need': np.int64(1749),
#  'surreal': np.int64(2607),
#  'resonant': np.int64(2175),
#  'passion': np.int64(1873),
#  'material': np.int64(1627),
#  'formula': np.int64(1052),
#  'wrong': np.int64(2985),
#  'wellcrafted': np.int64(2927),
#  'distance': np.int64(725),
#  'render': np.int64(2160),
#  'cheesy': np.int64(395),
#  'awe': np.int64(187),
#  'joyous': np.int64(1453),
#  'romp': np.int64(2220),
#  'nonstop': np.int64(1773),
#  'hoot': np.int64(1266),
#  'sabotage': np.int64(2233),
#  'torture': np.int64(2717),
#  'argentine': np.int64(132),
#  'remind': np.int64(2156),
#  'feelgood': np.int64(990),
#  'equally': np.int64(866),
#  'spoof': np.int64(2490),
#  'aspects': np.int64(155),
#  'white': np.int64(2936),
#  'package': np.int64(1844),
#  'timely': np.int64(2703),
#  'wrap': np.int64(2981),
#  'generic': np.int64(1105),
#  'crass': np.int64(568),
#  'frame': np.int64(1058),
#  'persona': np.int64(1901),
#  'plight': np.int64(1944),
#  'flamboyant': np.int64(1023),
#  'female': np.int64(992),
#  'cable': np.int64(331),
#  'channel': np.int64(377),
#  'appal': np.int64(120),
#  'amaze': np.int64(89),
#  'spiderman': np.int64(2478),
#  'stomachturning': np.int64(2527),
#  'violence': np.int64(2874),
#  'humanity': np.int64(1285),
#  'undeniable': np.int64(2788),
#  'mr': np.int64(1718),
#  'broomfield': np.int64(307),
#  'continue': np.int64(534),
#  'lesser': np.int64(1523),
#  'thriller': np.int64(2692),
#  'joke': np.int64(1446),
#  'wallace': np.int64(2893),
#  'complex': np.int64(493),
#  'wooden': np.int64(2969),
#  'lowkey': np.int64(1578),
#  'manner': np.int64(1608),
#  'burn': np.int64(324),
#  'strongest': np.int64(2550),
#  'brothers': np.int64(309),
#  'miss': np.int64(1683),
#  'outstanding': np.int64(1828),
#  'potent': np.int64(1983),
#  'seek': np.int64(2301),
#  'excitement': np.int64(906),
#  'insult': np.int64(1391),
#  'problems': np.int64(2024),
#  'fat': np.int64(976),
#  'greek': np.int64(1156),
#  'wed': np.int64(2917),
#  'focus': np.int64(1038),
#  'biopic': np.int64(240),
#  'document': np.int64(736),
#  'male': np.int64(1601),
#  'era': np.int64(870),
#  'signpost': np.int64(2371),
#  'mark': np.int64(1611),
#  'slow': np.int64(2413),
#  'linger': np.int64(1546),
#  'imagination': np.int64(1312),
#  'quirk': np.int64(2077),
#  'irrelevant': np.int64(1424),
#  'gradually': np.int64(1143),
#  'korean': np.int64(1484),
#  '2002': np.int64(6),
#  'historical': np.int64(1244),
#  'solid': np.int64(2436),
#  'assure': np.int64(162),
#  'complete': np.int64(491),
#  'modern': np.int64(1687),
#  'irony': np.int64(1423),
#  'road': np.int64(2207),
#  'thematic': np.int64(2680),
#  'obvious': np.int64(1796),
#  'sexual': np.int64(2336),
#  'politics': np.int64(1963),
#  'smug': np.int64(2424),
#  'formulaic': np.int64(1053),
#  'capture': np.int64(345),
#  'live': np.int64(1553),
#  'deserve': np.int64(672),
#  'pass': np.int64(1872),
#  'stupid': np.int64(2560),
#  'elements': np.int64(808),
#  'powerfully': np.int64(1990),
#  'mood': np.int64(1697),
#  'combine': np.int64(466),
#  'malaise': np.int64(1600),
#  'felt': np.int64(991),
#  'weird': np.int64(2922),
#  'finally': np.int64(1007),
#  'offensive': np.int64(1806),
#  'santa': np.int64(2250),
#  'children': np.int64(401),
#  'emotionally': np.int64(819),
#  'intimate': np.int64(1409),
#  'wish': np.int64(2953),
#  'loose': np.int64(1564),
#  'lazy': np.int64(1511),
#  'suspenseful': np.int64(2614),
#  'crackle': np.int64(564),
#  'fairly': np.int64(952),
#  'study': np.int64(2556),
#  'main': np.int64(1593),
#  'genial': np.int64(1107),
#  'job': np.int64(1444),
#  'husband': np.int64(1292),
#  'cliché': np.int64(440),
#  'book': np.int64(273),
#  'nonsensical': np.int64(1772),
#  'darker': np.int64(615),
#  'misogyny': np.int64(1682),
#  'suffocate': np.int64(2585),
#  'chill': np.int64(402),
#  'heartwarming': np.int64(1214),
#  'retread': np.int64(2183),
#  'reef': np.int64(2127),
#  'break': np.int64(286),
#  'deep': np.int64(640),
#  'deceptions': np.int64(636),
#  'unsettle': np.int64(2829),
#  'grand': np.int64(1144),
#  'goodnatured': np.int64(1133),
#  'audience': np.int64(177),
#  'nuanced': np.int64(1784),
#  'lead': np.int64(1512),
#  'star': np.int64(2504),
#  'selfindulgent': np.int64(2308),
#  'idiots': np.int64(1305),
#  'mental': np.int64(1654),
#  'punk': np.int64(2061),
#  'medium': np.int64(1643),
#  'hole': np.int64(1251),
#  'gap': np.int64(1094),
#  'pilot': np.int64(1925),
#  'team': np.int64(2644),
#  'blend': np.int64(257),
#  'chabrol': np.int64(372),
#  'master': np.int64(1622),
#  'innuendo': np.int64(1375),
#  'rivet': np.int64(2206),
#  'war': np.int64(2899),
#  'screenplay': np.int64(2285),
#  'bore': np.int64(275),
#  'mesmerize': np.int64(1659),
#  'thoughtful': np.int64(2687),
#  'raw': np.int64(2097),
#  'comingofage': np.int64(476),
#  'tale': np.int64(2629),
#  'drug': np.int64(764),
#  'testament': np.int64(2672),
#  ...}

# %%
# Calculate statistical similarity
sim_5_100_tfidf = cosine_similarity(train_tfidf_lemma[4].toarray()[0],
                             train_tfidf_lemma[99].toarray()[0])
sim_5_15000_tfidf = cosine_similarity(train_tfidf_lemma[4].toarray()[0],
                               train_tfidf_lemma[14999].toarray()[0])
sim_5_50000_tfidf = cosine_similarity(train_tfidf_lemma[4].toarray()[0],
                               train_tfidf_lemma[49999].toarray()[0])

# %%
print(f"{lemma_train[4]} \n {sim_5_100_tfidf} \n {lemma_train[99]}")
# Out:
# worst revengeofthenerds clichés filmmakers could dredge
#  0.0
#  act direct clear washington certainly new career ahead

# %%
print(f"{lemma_train[4]} \n {sim_5_15000_tfidf} \n {lemma_train[14999]}")
# Out:
# worst revengeofthenerds clichés filmmakers could dredge
#  0.0
#  eloquent

# %%
print(f"{lemma_train[4]} \n {sim_5_50000_tfidf} \n {lemma_train[49999]}")
# Out:
# worst revengeofthenerds clichés filmmakers could dredge
#  0.0
#  stylish

# %% [markdown]
# **stemmed sentences**

# %%
# Calculate TF-IDF - stemmed sentences
train_tfidf_stem = tfidf_vectorizer.fit_transform(stem_train) # Learn vocabulary from training
val_tfidf_stem = tfidf_vectorizer.transform(stem_val) # Apply to validation

# %%
# Get vocabulary and tokens after fitting
vocabulary_tfidf = tfidf_vectorizer.vocabulary_
tokens_tfidf = tfidf_vectorizer.get_feature_names_out()

# %%
vocabulary_tfidf
# Out:
# {'hide': np.int64(1228),
#  'new': np.int64(1757),
#  'secret': np.int64(2283),
#  'parent': np.int64(1870),
#  'unit': np.int64(2817),
#  'contain': np.int64(539),
#  'wit': np.int64(2954),
#  'labor': np.int64(1484),
#  'gag': np.int64(1087),
#  'love': np.int64(1573),
#  'charact': np.int64(395),
#  'commun': np.int64(490),
#  'someth': np.int64(2431),
#  'beauti': np.int64(226),
#  'human': np.int64(1278),
#  'natur': np.int64(1747),
#  'remain': np.int64(2136),
#  'utterli': np.int64(2846),
#  'satisfi': np.int64(2240),
#  'worst': np.int64(2974),
#  'cliché': np.int64(452),
#  'filmmak': np.int64(1002),
#  'far': np.int64(967),
#  'tragic': np.int64(2731),
#  'merit': np.int64(1658),
#  'superfici': np.int64(2596),
#  'treatment': np.int64(2745),
#  'demonstr': np.int64(671),
#  'director': np.int64(714),
#  'hollywood': np.int64(1252),
#  'blockbust': np.int64(266),
#  'game': np.int64(1089),
#  'turn': np.int64(2767),
#  'small': np.int64(2405),
#  'person': np.int64(1905),
#  'film': np.int64(1001),
#  'emot': np.int64(830),
#  'wallop': np.int64(2891),
#  'depress': np.int64(680),
#  'poetri': np.int64(1955),
#  'deepli': np.int64(652),
#  'thought': np.int64(2687),
#  'goe': np.int64(1125),
#  'absurd': np.int64(25),
#  'length': np.int64(1523),
#  'moviego': np.int64(1725),
#  'nt': np.int64(1792),
#  'make': np.int64(1602),
#  'movi': np.int64(1724),
#  'like': np.int64(1540),
#  'use': np.int64(2842),
#  'noth': np.int64(1785),
#  'happen': np.int64(1189),
#  'saw': np.int64(2247),
#  'bad': np.int64(200),
#  'lend': np.int64(1522),
#  'digniti': np.int64(707),
#  'dumb': np.int64(784),
#  'stori': np.int64(2527),
#  'greatest': np.int64(1150),
#  'musician': np.int64(1737),
#  'cold': np.int64(471),
#  'usual': np.int64(2844),
#  'intellig': np.int64(1390),
#  'subtleti': np.int64(2573),
#  'redund': np.int64(2113),
#  'concept': np.int64(510),
#  'swim': np.int64(2623),
#  'young': np.int64(2994),
#  'woman': np.int64(2961),
#  'face': np.int64(945),
#  'cast': np.int64(371),
#  'actress': np.int64(43),
#  'project': np.int64(2029),
#  'doubt': np.int64(752),
#  'yearn': np.int64(2991),
#  'succe': np.int64(2576),
#  'equal': np.int64(873),
#  'origin': np.int64(1829),
#  'way': np.int64(2909),
#  'better': np.int64(240),
#  'anyth': np.int64(128),
#  'black': np.int64(253),
#  'camp': np.int64(352),
#  'conspiraci': np.int64(534),
#  'dirti': np.int64(717),
#  'smile': np.int64(2410),
#  'come': np.int64(478),
#  'perform': np.int64(1901),
#  'unfunni': np.int64(2811),
#  'piti': np.int64(1933),
#  'imagin': np.int64(1309),
#  'mix': np.int64(1691),
#  'antic': np.int64(123),
#  'spirit': np.int64(2476),
#  'half': np.int64(1179),
#  'dragonfli': np.int64(759),
#  'wors': np.int64(2973),
#  'world': np.int64(2971),
#  'cinema': np.int64(435),
#  'good': np.int64(1127),
#  'view': np.int64(2867),
#  'altern': np.int64(92),
#  'plot': np.int64(1947),
#  'start': np.int64(2499),
#  'finish': np.int64(1007),
#  'action': np.int64(40),
#  'stilt': np.int64(2514),
#  'cylind': np.int64(615),
#  'littl': np.int64(1551),
#  'preachi': np.int64(1989),
#  'poorli': np.int64(1971),
#  'act': np.int64(39),
#  'year': np.int64(2990),
#  'sit': np.int64(2376),
#  'anoth': np.int64(119),
#  'best': np.int64(238),
#  'man': np.int64(1606),
#  'weav': np.int64(2912),
#  'theme': np.int64(2682),
#  'funni': np.int64(1080),
#  'issu': np.int64(1419),
#  'adult': np.int64(59),
#  'marriag': np.int64(1617),
#  'think': np.int64(2685),
#  'real': np.int64(2088),
#  'silli': np.int64(2358),
#  'crude': np.int64(602),
#  'storylin': np.int64(2528),
#  'hero': np.int64(1222),
#  'exist': np.int64(916),
#  'entir': np.int64(867),
#  'point': np.int64(1958),
#  'dog': np.int64(748),
#  'cours': np.int64(574),
#  'nowher': np.int64(1791),
#  'classic': np.int64(445),
#  'everi': np.int64(893),
#  'sens': np.int64(2299),
#  'sometim': np.int64(2432),
#  'dri': np.int64(771),
#  'alreadi': np.int64(91),
#  'recycl': np.int64(2108),
#  'time': np.int64(2700),
#  'care': np.int64(362),
#  'count': np.int64(570),
#  'cover': np.int64(575),
#  'territori': np.int64(2670),
#  'suggest': np.int64(2587),
#  'featur': np.int64(986),
#  '40': np.int64(12),
#  'million': np.int64(1675),
#  'version': np.int64(2860),
#  'gorgeou': np.int64(1131),
#  'decept': np.int64(645),
#  'minimalist': np.int64(1679),
#  'cross': np.int64(598),
#  'prove': np.int64(2038),
#  'lost': np.int64(1569),
#  'touch': np.int64(2723),
#  'bring': np.int64(311),
#  'superb': np.int64(2595),
#  'admittedli': np.int64(55),
#  'middl': np.int64(1667),
#  'disappoint': np.int64(718),
#  'horror': np.int64(1268),
#  'muddl': np.int64(1729),
#  'splash': np.int64(2479),
#  'bloodi': np.int64(269),
#  'vivid': np.int64(2880),
#  'scorses': np.int64(2266),
#  'given': np.int64(1114),
#  'mani': np.int64(1610),
#  'pointless': np.int64(1959),
#  'contriv': np.int64(549),
#  'situat': np.int64(2378),
#  'poor': np.int64(1970),
#  'drive': np.int64(772),
#  'direct': np.int64(712),
#  'subtl': np.int64(2571),
#  'son': np.int64(2435),
#  'room': np.int64(2203),
#  'sophist': np.int64(2438),
#  'rich': np.int64(2176),
#  'vein': np.int64(2857),
#  'stuff': np.int64(2554),
#  'appar': np.int64(132),
#  'joy': np.int64(1446),
#  'shot': np.int64(2344),
#  'ugli': np.int64(2773),
#  'digit': np.int64(706),
#  'video': np.int64(2865),
#  'sour': np.int64(2449),
#  'core': np.int64(563),
#  'explor': np.int64(928),
#  'empti': np.int64(838),
#  'end': np.int64(843),
#  'capabl': np.int64(356),
#  'hold': np.int64(1247),
#  'thrill': np.int64(2690),
#  'pretti': np.int64(2003),
#  'damn': np.int64(620),
#  'feel': np.int64(989),
#  'lousi': np.int64(1572),
#  'record': np.int64(2105),
#  'industri': np.int64(1351),
#  'current': np.int64(611),
#  'togeth': np.int64(2707),
#  'magnific': np.int64(1596),
#  'swoop': np.int64(2625),
#  'breathtak': np.int64(301),
#  'overal': np.int64(1836),
#  'experi': np.int64(923),
#  'sound': np.int64(2447),
#  'cruel': np.int64(604),
#  'carri': np.int64(366),
#  'men': np.int64(1652),
#  'margin': np.int64(1614),
#  'idea': np.int64(1295),
#  'women': np.int64(2962),
#  'total': np.int64(2722),
#  'lack': np.int64(1485),
#  'empathi': np.int64(831),
#  'fresh': np.int64(1067),
#  'histori': np.int64(1242),
#  'eastwood': np.int64(801),
#  'pay': np.int64(1890),
#  'earnest': np.int64(795),
#  'homag': np.int64(1255),
#  'weak': np.int64(2910),
#  'skip': np.int64(2383),
#  'dreck': np.int64(768),
#  'laugh': np.int64(1503),
#  'surpris': np.int64(2607),
#  'affirm': np.int64(65),
#  'power': np.int64(1986),
#  'help': np.int64(1220),
#  'peopl': np.int64(1896),
#  'endur': np.int64(848),
#  'unimagin': np.int64(2812),
#  'absolut': np.int64(22),
#  'gener': np.int64(1100),
#  'life': np.int64(1531),
#  'fun': np.int64(1078),
#  'high': np.int64(1230),
#  'low': np.int64(1575),
#  'base': np.int64(218),
#  'true': np.int64(2760),
#  'histor': np.int64(1241),
#  'signific': np.int64(2356),
#  'tribut': np.int64(2750),
#  'actor': np.int64(42),
#  'throw': np.int64(2692),
#  'spark': np.int64(2455),
#  'appear': np.int64(134),
#  'ca': np.int64(343),
#  'heat': np.int64(1212),
#  'comedi': np.int64(480),
#  'robert': np.int64(2190),
#  'deniro': np.int64(674),
#  'manag': np.int64(1607),
#  'terrif': np.int64(2668),
#  'flair': np.int64(1017),
#  'extrem': np.int64(939),
#  'farc': np.int64(968),
#  'famili': np.int64(960),
#  'intens': np.int64(1392),
#  'fashion': np.int64(973),
#  'engross': np.int64(854),
#  'entertain': np.int64(862),
#  'anim': np.int64(117),
#  'written': np.int64(2985),
#  'believ': np.int64(231),
#  'anyon': np.int64(127),
#  'central': np.int64(382),
#  'creation': np.int64(586),
#  'comic': np.int64(484),
#  'parodi': np.int64(1873),
#  'melodrama': np.int64(1647),
#  'toss': np.int64(2721),
#  'intrigu': np.int64(1404),
#  'question': np.int64(2060),
#  'differ': np.int64(704),
#  'moment': np.int64(1698),
#  'subvers': np.int64(2575),
#  'follow': np.int64(1039),
#  'stale': np.int64(2494),
#  'standard': np.int64(2496),
#  'becom': np.int64(227),
#  'underbelli': np.int64(2789),
#  'crimin': np.int64(595),
#  'overbear': np.int64(1837),
#  'overthetop': np.int64(1844),
#  'duval': np.int64(787),
#  'sudden': np.int64(2583),
#  'wisdom': np.int64(2951),
#  'clear': np.int64(447),
#  'washington': np.int64(2903),
#  'certainli': np.int64(386),
#  'career': np.int64(363),
#  'ahead': np.int64(72),
#  'memori': np.int64(1651),
#  'respect': np.int64(2160),
#  'grate': np.int64(1145),
#  'showcas': np.int64(2347),
#  'hate': np.int64(1201),
#  'tear': np.int64(2647),
#  'eye': np.int64(941),
#  'away': np.int64(193),
#  'imag': np.int64(1307),
#  'long': np.int64(1561),
#  'read': np.int64(2087),
#  'subtitl': np.int64(2570),
#  'addit': np.int64(50),
#  'sport': np.int64(2486),
#  'titl': np.int64(2705),
#  'recent': np.int64(2099),
#  'cinemat': np.int64(436),
#  'quit': np.int64(2067),
#  'build': np.int64(332),
#  'theater': np.int64(2679),
#  'late': np.int64(1499),
#  'mysteri': np.int64(1739),
#  'scienc': np.int64(2259),
#  'killer': np.int64(1467),
#  'websit': np.int64(2914),
#  'work': np.int64(2970),
#  'concert': np.int64(513),
#  'fluid': np.int64(1034),
#  'nononsens': np.int64(1777),
#  'author': np.int64(185),
#  'harri': np.int64(1194),
#  'seal': np.int64(2277),
#  'deal': np.int64(639),
#  'gone': np.int64(1126),
#  'step': np.int64(2507),
#  'harsh': np.int64(1196),
#  'piec': np.int64(1925),
#  'storytel': np.int64(2529),
#  'attract': np.int64(181),
#  'talent': np.int64(2634),
#  'landscap': np.int64(1490),
#  'creat': np.int64(585),
#  'wickedli': np.int64(2939),
#  'watch': np.int64(2905),
#  'provid': np.int64(2039),
#  'pleasur': np.int64(1943),
#  'altogeth': np.int64(93),
#  'slight': np.int64(2395),
#  'kind': np.int64(1468),
#  'masterpiec': np.int64(1625),
#  'mayb': np.int64(1632),
#  'twice': np.int64(2769),
#  'complet': np.int64(500),
#  'forgotten': np.int64(1048),
#  'car': np.int64(361),
#  'park': np.int64(1871),
#  'lot': np.int64(1570),
#  'charm': np.int64(401),
#  'quirki': np.int64(2066),
#  'match': np.int64(1626),
#  'pure': np.int64(2052),
#  'old': np.int64(1814),
#  'colleg': np.int64(474),
#  'tri': np.int64(2748),
#  'wellwritten': np.int64(2926),
#  'wellact': np.int64(2922),
#  'conclus': np.int64(515),
#  'answer': np.int64(120),
#  'clumsi': np.int64(465),
#  'dialogu': np.int64(700),
#  'heavyhand': np.int64(1215),
#  'sentiment': np.int64(2304),
#  'trifl': np.int64(2752),
#  'unfortun': np.int64(2809),
#  'cute': np.int64(614),
#  'budget': np.int64(330),
#  'betray': np.int64(239),
#  'surprisingli': np.int64(2608),
#  'shoddi': np.int64(2341),
#  'proper': np.int64(2031),
#  'convict': np.int64(556),
#  'role': np.int64(2196),
#  'jason': np.int64(1430),
#  'bourn': np.int64(290),
#  'great': np.int64(1148),
#  'poignant': np.int64(1957),
#  'artist': np.int64(154),
#  'effort': np.int64(814),
#  'share': np.int64(2332),
#  'impress': np.int64(1323),
#  'loss': np.int64(1568),
#  'art': np.int64(149),
#  'suprem': np.int64(2602),
#  'middleag': np.int64(1668),
#  'live': np.int64(1552),
#  'engag': np.int64(852),
#  'examin': np.int64(904),
#  'similar': np.int64(2359),
#  'obsess': np.int64(1801),
#  'irrit': np.int64(1418),
#  'collaps': np.int64(472),
#  'challeng': np.int64(389),
#  'forgiv': np.int64(1047),
#  'flaw': np.int64(1025),
#  'serv': np.int64(2312),
#  'learn': np.int64(1514),
#  'tool': np.int64(2716),
#  'big': np.int64(241),
#  'excus': np.int64(912),
#  'play': np.int64(1938),
#  'scene': np.int64(2253),
#  'effect': np.int64(812),
#  'stick': np.int64(2511),
#  'import': np.int64(1321),
#  'tradit': np.int64(2728),
#  'deliv': np.int64(665),
#  'promis': np.int64(2030),
#  'look': np.int64(1563),
#  'wild': np.int64(2942),
#  'ride': np.int64(2180),
#  'set': np.int64(2314),
#  'cell': np.int64(379),
#  'phone': np.int64(1913),
#  'sketchi': np.int64(2380),
#  'busi': np.int64(341),
#  'suppos': np.int64(2601),
#  'ridicul': np.int64(2181),
#  'tast': np.int64(2641),
#  'rock': np.int64(2193),
#  'roll': np.int64(2197),
#  'suspens': np.int64(2615),
#  'consist': np.int64(531),
#  'realist': np.int64(2090),
#  'portray': np.int64(1977),
#  'grab': np.int64(1136),
#  'lump': np.int64(1584),
#  'squeez': np.int64(2491),
#  'stunt': np.int64(2556),
#  'reveal': np.int64(2167),
#  'special': np.int64(2459),
#  'servic': np.int64(2313),
#  'welcom': np.int64(2921),
#  'relief': np.int64(2135),
#  'easili': np.int64(800),
#  'wait': np.int64(2886),
#  'justifi': np.int64(1456),
#  'theatric': np.int64(2680),
#  'death': np.int64(640),
#  'extraordinari': np.int64(937),
#  'faith': np.int64(955),
#  'seen': np.int64(2287),
#  'heart': np.int64(1208),
#  'adapt': np.int64(47),
#  'sure': np.int64(2603),
#  'salton': np.int64(2230),
#  'sea': np.int64(2275),
#  'noir': np.int64(1772),
#  'tight': np.int64(2699),
#  'nasti': np.int64(1745),
#  'overlong': np.int64(1843),
#  'bombast': np.int64(280),
#  'deriv': np.int64(682),
#  'audaci': np.int64(182),
#  'outrag': np.int64(1832),
#  'disney': np.int64(732),
#  'sequel': np.int64(2306),
#  'final': np.int64(1003),
#  'suck': np.int64(2581),
#  'despit': np.int64(689),
#  'eat': np.int64(802),
#  'argu': np.int64(143),
#  'fight': np.int64(999),
#  'problem': np.int64(2015),
#  'ambit': np.int64(99),
#  'laudabl': np.int64(1502),
#  'compel': np.int64(496),
#  'infecti': np.int64(1356),
#  'pictur': np.int64(1922),
#  'run': np.int64(2212),
#  'mere': np.int64(1657),
#  'minut': np.int64(1681),
#  'remark': np.int64(2138),
#  'process': np.int64(2019),
#  'sweep': np.int64(2620),
#  'romanc': np.int64(2200),
#  'genr': np.int64(1102),
#  'passabl': np.int64(1879),
#  'date': np.int64(628),
#  'imax': np.int64(1310),
#  'short': np.int64(2343),
#  'pleasant': np.int64(1941),
#  'ooz': np.int64(1818),
#  'involv': np.int64(1410),
#  'save': np.int64(2244),
#  'dash': np.int64(627),
#  'slightest': np.int64(2396),
#  'wildli': np.int64(2943),
#  'uneven': np.int64(2800),
#  'poke': np.int64(1960),
#  'provok': np.int64(2041),
#  'spear': np.int64(2458),
#  'music': np.int64(1736),
#  'content': np.int64(542),
#  '90': np.int64(17),
#  'want': np.int64(2895),
#  'color': np.int64(476),
#  'depth': np.int64(681),
#  'ingeni': np.int64(1361),
#  'abl': np.int64(21),
#  'hit': np.int64(1244),
#  '100': np.int64(1),
#  'troubl': np.int64(2759),
#  'day': np.int64(634),
#  'note': np.int64(1784),
#  'sciencefict': np.int64(2260),
#  'narr': np.int64(1743),
#  'style': np.int64(2558),
#  'frustrat': np.int64(1074),
#  'difficult': np.int64(705),
#  'unpredict': np.int64(2826),
#  'scream': np.int64(2269),
#  'ii': np.int64(1302),
#  'achiev': np.int64(37),
#  'ultim': np.int64(2774),
#  'insignific': np.int64(1374),
#  'scifi': np.int64(2262),
#  'spectacl': np.int64(2462),
#  'epic': np.int64(871),
#  'fan': np.int64(963),
#  'hardli': np.int64(1192),
#  'ask': np.int64(159),
#  'plod': np.int64(1946),
#  'drama': np.int64(761),
#  'reach': np.int64(2085),
#  'translat': np.int64(2735),
#  'speak': np.int64(2457),
#  'forc': np.int64(1043),
#  'ponder': np.int64(1968),
#  'space': np.int64(2452),
#  'larg': np.int64(1495),
#  'consider': np.int64(530),
#  'aplomb': np.int64(130),
#  'cobbl': np.int64(467),
#  'flat': np.int64(1022),
#  'inan': np.int64(1328),
#  'aw': np.int64(189),
#  'told': np.int64(2709),
#  'scatter': np.int64(2251),
#  'chanc': np.int64(391),
#  'bold': np.int64(278),
#  'studio': np.int64(2553),
#  'actual': np.int64(44),
#  'thing': np.int64(2684),
#  'fear': np.int64(982),
#  'mess': np.int64(1660),
#  'infus': np.int64(1360),
#  'path': np.int64(1883),
#  'flash': np.int64(1019),
#  'warmth': np.int64(2899),
#  'gentl': np.int64(1103),
#  'humor': np.int64(1280),
#  'sensit': np.int64(2302),
#  'script': np.int64(2273),
#  'avoid': np.int64(188),
#  'pitfal': np.int64(1932),
#  'expect': np.int64(921),
#  'potenti': np.int64(1983),
#  'setup': np.int64(2316),
#  'load': np.int64(1553),
#  'credit': np.int64(590),
#  'girl': np.int64(1113),
#  'bar': np.int64(211),
#  'enjoy': np.int64(856),
#  'add': np.int64(48),
#  'dark': np.int64(624),
#  'vision': np.int64(2876),
#  'predecessor': np.int64(1992),
#  'ye': np.int64(2989),
#  'pace': np.int64(1849),
#  'unpleas': np.int64(2825),
#  'affair': np.int64(63),
#  'incred': np.int64(1342),
#  'anticip': np.int64(124),
#  'predict': np.int64(1993),
#  'brilliant': np.int64(308),
#  'profession': np.int64(2023),
#  'unassum': np.int64(2778),
#  'technic': np.int64(2649),
#  'posit': np.int64(1978),
#  'chang': np.int64(392),
#  'tone': np.int64(2713),
#  'beat': np.int64(225),
#  'innov': np.int64(1368),
#  'dim': np.int64(708),
#  'goofi': np.int64(1130),
#  'teem': np.int64(2654),
#  'kid': np.int64(1463),
#  'insid': np.int64(1372),
#  'laughabl': np.int64(1504),
#  'watchabl': np.int64(2906),
#  'valu': np.int64(2848),
#  'term': np.int64(2665),
#  'dentist': np.int64(675),
#  'honest': np.int64(1257),
#  'amazingli': np.int64(97),
#  'lame': np.int64(1488),
#  'straightforward': np.int64(2531),
#  'disappointingli': np.int64(719),
#  'slice': np.int64(2393),
#  'gem': np.int64(1099),
#  'delight': np.int64(664),
#  'spare': np.int64(2454),
#  'photographi': np.int64(1916),
#  'understand': np.int64(2795),
#  'plain': np.int64(1936),
#  'structur': np.int64(2548),
#  'frida': np.int64(1068),
#  'adventur': np.int64(61),
#  'indian': np.int64(1346),
#  'market': np.int64(1616),
#  'worth': np.int64(2975),
#  'price': np.int64(2006),
#  'gori': np.int64(1133),
#  'mayhem': np.int64(1633),
#  'produc': np.int64(2020),
#  'jerri': np.int64(1434),
#  'bruckheim': np.int64(325),
#  'joel': np.int64(1438),
#  'reflect': np.int64(2118),
#  'shallow': np.int64(2325),
#  'motiv': np.int64(1718),
#  'demograph': np.int64(669),
#  'target': np.int64(2640),
#  'pleas': np.int64(1940),
#  'blair': np.int64(255),
#  'witch': np.int64(2955),
#  'footag': np.int64(1042),
#  'second': np.int64(2281),
#  'folli': np.int64(1038),
#  'tediou': np.int64(2652),
#  'offer': np.int64(1812),
#  'oscar': np.int64(1830),
#  'nomin': np.int64(1774),
#  'esther': np.int64(885),
#  'unusu': np.int64(2834),
#  'stylish': np.int64(2559),
#  'exercis': np.int64(914),
#  'halfway': np.int64(1180),
#  'begin': np.int64(228),
#  'easi': np.int64(798),
#  'border': np.int64(284),
#  'thoroughli': np.int64(2686),
#  'grip': np.int64(1158),
#  'hard': np.int64(1191),
#  'distract': np.int64(741),
#  'fascin': np.int64(972),
#  'gun': np.int64(1172),
#  'cheat': np.int64(407),
#  'martial': np.int64(1619),
#  'comput': np.int64(507),
#  'camera': np.int64(351),
#  'breezi': np.int64(303),
#  'rhythm': np.int64(2175),
#  'sumptuou': np.int64(2592),
#  'stream': np.int64(2535),
#  'slick': np.int64(2394),
#  'manufactur': np.int64(1613),
#  'claim': np.int64(440),
#  'street': np.int64(2536),
#  'credibl': np.int64(589),
#  'nice': np.int64(1760),
#  'valuabl': np.int64(2849),
#  'messag': np.int64(1661),
#  'thank': np.int64(2678),
#  'guy': np.int64(1174),
#  'desper': np.int64(688),
#  'tarantino': np.int64(2639),
#  'grow': np.int64(1165),
#  'essenti': np.int64(883),
#  'collect': np.int64(473),
#  'bit': np.int64(248),
#  'rest': np.int64(2162),
#  'elev': np.int64(822),
#  'hugh': np.int64(1277),
#  'grant': np.int64(1142),
#  'line': np.int64(1543),
#  'arriv': np.int64(148),
#  'earli': np.int64(793),
#  'stay': np.int64(2505),
#  'genuin': np.int64(1105),
#  'insight': np.int64(1373),
#  'urban': np.int64(2839),
#  'hour': np.int64(1272),
#  'john': np.int64(1439),
#  'blue': np.int64(272),
#  'green': np.int64(1152),
#  'brown': np.int64(323),
#  'organ': np.int64(1828),
#  'crime': np.int64(594),
#  'includ': np.int64(1333),
#  'lane': np.int64(1491),
#  'richard': np.int64(2177),
#  'ludicr': np.int64(1582),
#  'skill': np.int64(2381),
#  'steven': np.int64(2510),
#  'seagal': np.int64(2276),
#  'warm': np.int64(2898),
#  'water': np.int64(2907),
#  'red': np.int64(2109),
#  'bridg': np.int64(304),
#  'celebr': np.int64(378),
#  'energi': np.int64(851),
#  'heal': np.int64(1205),
#  'sensat': np.int64(2300),
#  'reallif': np.int64(2094),
#  'metaphor': np.int64(1663),
#  'home': np.int64(1256),
#  'leav': np.int64(1515),
#  'mention': np.int64(1656),
#  'retain': np.int64(2164),
#  'ambigu': np.int64(98),
#  'ad': np.int64(45),
#  'reson': np.int64(2158),
#  'format': np.int64(1051),
#  'oldfashion': np.int64(1816),
#  'educ': np.int64(810),
#  'viewer': np.int64(2868),
#  'word': np.int64(2969),
#  'handsom': np.int64(1188),
#  'unfulfil': np.int64(2810),
#  'charmless': np.int64(403),
#  'haunt': np.int64(1202),
#  'debut': np.int64(642),
#  'fine': np.int64(1004),
#  'aim': np.int64(75),
#  'mainli': np.int64(1598),
#  'plenti': np.int64(1944),
#  'grownup': np.int64(1166),
#  'seat': np.int64(2280),
#  'everyth': np.int64(895),
#  'observ': np.int64(1800),
#  'secondhand': np.int64(2282),
#  'familiar': np.int64(961),
#  'spot': np.int64(2487),
#  'player': np.int64(1939),
#  'gift': np.int64(1112),
#  'contribut': np.int64(548),
#  'choppi': np.int64(427),
#  'school': np.int64(2257),
#  'sex': np.int64(2319),
#  'demand': np.int64(667),
#  'receiv': np.int64(2098),
#  'excel': np.int64(908),
#  'blast': np.int64(259),
#  'adrenalin': np.int64(58),
#  'escap': np.int64(880),
#  'kick': np.int64(1462),
#  'cultur': np.int64(607),
#  'horrifi': np.int64(1267),
#  'mourn': np.int64(1721),
#  'tragedi': np.int64(2730),
#  'privat': np.int64(2012),
#  'gain': np.int64(1088),
#  'momentum': np.int64(1699),
#  'sand': np.int64(2232),
#  'pale': np.int64(1858),
#  'characterist': np.int64(397),
#  'jaglom': np.int64(1425),
#  'honestli': np.int64(1259),
#  'affect': np.int64(64),
#  'sorvino': np.int64(2444),
#  'limit': np.int64(1541),
#  'success': np.int64(2578),
#  'level': np.int64(1528),
#  'miser': np.int64(1684),
#  'accomplish': np.int64(32),
#  'approach': np.int64(137),
#  'irish': np.int64(1412),
#  'exhilar': np.int64(915),
#  'bound': np.int64(289),
#  'appeal': np.int64(133),
#  'trashi': np.int64(2740),
#  'trash': np.int64(2739),
#  'right': np.int64(2182),
#  'summer': np.int64(2591),
#  'sustain': np.int64(2616),
#  'endear': np.int64(844),
#  'howev': np.int64(1275),
#  'especi': np.int64(881),
#  'ambiti': np.int64(100),
#  'sister': np.int64(2374),
#  'subject': np.int64(2563),
#  'matter': np.int64(1629),
#  'incompet': np.int64(1335),
#  'alway': np.int64(94),
#  'droll': np.int64(773),
#  'whimsi': np.int64(2933),
#  'overcom': np.int64(1839),
#  'parker': np.int64(1872),
#  'creativ': np.int64(587),
#  'root': np.int64(2204),
#  'fate': np.int64(978),
#  'casual': np.int64(372),
#  'ode': np.int64(1808),
#  'walk': np.int64(2888),
#  'horribl': np.int64(1266),
#  'terribl': np.int64(2667),
#  'stage': np.int64(2493),
#  'screen': np.int64(2270),
#  'ellen': np.int64(824),
#  'pompeo': np.int64(1967),
#  'giant': np.int64(1110),
#  'copi': np.int64(562),
#  'excit': np.int64(910),
#  'interview': np.int64(1398),
#  'evoc': np.int64(898),
#  'decad': np.int64(643),
#  'ago': np.int64(71),
#  'fail': np.int64(949),
#  'caught': np.int64(375),
#  'compani': np.int64(491),
#  'astonish': np.int64(168),
#  'growth': np.int64(1167),
#  'frozen': np.int64(1073),
#  'soap': np.int64(2416),
#  'opera': np.int64(1822),
#  'simpli': np.int64(2364),
#  'free': np.int64(1063),
#  'tv': np.int64(2768),
#  'giddi': np.int64(1111),
#  'choos': np.int64(425),
#  'open': np.int64(1820),
#  'wound': np.int64(2978),
#  'suffer': np.int64(2584),
#  'failur': np.int64(950),
#  'hoffman': np.int64(1245),
#  'clinic': np.int64(455),
#  'wonder': np.int64(2963),
#  'cinematographi': np.int64(437),
#  'highconcept': np.int64(1231),
#  'vulgar': np.int64(2884),
#  'refus': np.int64(2122),
#  'reason': np.int64(2095),
#  'confus': np.int64(523),
#  'need': np.int64(1753),
#  'surreal': np.int64(2609),
#  'passion': np.int64(1880),
#  'materi': np.int64(1627),
#  'formula': np.int64(1052),
#  'wrong': np.int64(2986),
#  'wellcraft': np.int64(2923),
#  'distanc': np.int64(736),
#  'render': np.int64(2143),
#  'cheesi': np.int64(411),
#  'sinc': np.int64(2368),
#  'awe': np.int64(194),
#  'joyou': np.int64(1448),
#  'romp': np.int64(2202),
#  'nonstop': np.int64(1779),
#  'hoot': np.int64(1263),
#  'sabotag': np.int64(2217),
#  'tortur': np.int64(2720),
#  'argentin': np.int64(142),
#  'remind': np.int64(2140),
#  'feelgood': np.int64(990),
#  'spoof': np.int64(2484),
#  'aspect': np.int64(160),
#  'white': np.int64(2936),
#  'packag': np.int64(1851),
#  'wrap': np.int64(2980),
#  'crass': np.int64(582),
#  'frame': np.int64(1057),
#  'vulner': np.int64(2885),
#  'persona': np.int64(1906),
#  'plight': np.int64(1945),
#  'flamboy': np.int64(1018),
#  'femal': np.int64(992),
#  'squar': np.int64(2490),
#  'cabl': np.int64(344),
#  'channel': np.int64(393),
#  'appal': np.int64(131),
#  'amaz': np.int64(96),
#  'spiderman': np.int64(2472),
#  'stomachturn': np.int64(2522),
#  'violenc': np.int64(2872),
#  'undeni': np.int64(2788),
#  'mr': np.int64(1727),
#  'broomfield': np.int64(320),
#  'continu': np.int64(545),
#  'lesser': np.int64(1525),
#  'thriller': np.int64(2691),
#  'joke': np.int64(1440),
#  'wallac': np.int64(2889),
#  'complex': np.int64(501),
#  'wooden': np.int64(2967),
#  'lowkey': np.int64(1580),
#  'manner': np.int64(1612),
#  'burn': np.int64(339),
#  'strongest': np.int64(2546),
#  'brother': np.int64(321),
#  'miss': np.int64(1689),
#  'outstand': np.int64(1834),
#  'potent': np.int64(1982),
#  'write': np.int64(2982),
#  'seek': np.int64(2285),
#  'insult': np.int64(1384),
#  'fat': np.int64(976),
#  'greek': np.int64(1151),
#  'wed': np.int64(2915),
#  'popular': np.int64(1975),
#  'focu': np.int64(1035),
#  'biopic': np.int64(246),
#  'document': np.int64(746),
#  'male': np.int64(1605),
#  'era': np.int64(877),
#  'signpost': np.int64(2357),
#  'mark': np.int64(1615),
#  'slow': np.int64(2401),
#  'linger': np.int64(1544),
#  'quirk': np.int64(2065),
#  'seriou': np.int64(2310),
#  'irrelev': np.int64(1415),
#  'gradual': np.int64(1139),
#  'describ': np.int64(683),
#  'korean': np.int64(1481),
#  '2002': np.int64(8),
#  'solid': np.int64(2424),
#  'assur': np.int64(167),
#  'modern': np.int64(1694),
#  'ironi': np.int64(1414),
#  'road': np.int64(2189),
#  'themat': np.int64(2681),
#  'obviou': np.int64(1802),
#  'sexual': np.int64(2321),
#  'polit': np.int64(1965),
#  'smug': np.int64(2411),
#  'captur': np.int64(360),
#  'deserv': np.int64(684),
#  'pass': np.int64(1878),
#  'stupid': np.int64(2557),
#  'element': np.int64(821),
#  'mood': np.int64(1707),
#  'combin': np.int64(477),
#  'malais': np.int64(1604),
#  'felt': np.int64(991),
#  'weird': np.int64(2919),
#  'offens': np.int64(1811),
#  'santa': np.int64(2236),
#  'children': np.int64(417),
#  'intim': np.int64(1399),
#  'wish': np.int64(2953),
#  'loos': np.int64(1564),
#  'lazi': np.int64(1509),
#  'crackl': np.int64(578),
#  'fairli': np.int64(953),
#  'studi': np.int64(2552),
#  'main': np.int64(1597),
#  'genial': np.int64(1101),
#  'job': np.int64(1437),
#  'husband': np.int64(1287),
#  'thrown': np.int64(2693),
#  'book': np.int64(283),
#  'nonsens': np.int64(1778),
#  'darker': np.int64(625),
#  'misogyni': np.int64(1688),
#  'suffoc': np.int64(2585),
#  'illumin': np.int64(1305),
#  'daughter': np.int64(629),
#  'chill': np.int64(418),
#  'heartwarm': np.int64(1211),
#  'retread': np.int64(2165),
#  'reef': np.int64(2114),
#  'surviv': np.int64(2612),
#  'break': np.int64(298),
#  'deep': np.int64(650),
#  'unsettl': np.int64(2830),
#  'spooki': np.int64(2485),
#  'supernatur': np.int64(2598),
#  'grand': np.int64(1140),
#  'goodnatur': np.int64(1129),
#  'audienc': np.int64(183),
#  'nuanc': np.int64(1793),
#  'lead': np.int64(1510),
#  'star': np.int64(2497),
#  'selfindulg': np.int64(2295),
#  'idiot': np.int64(1300),
#  'mental': np.int64(1655),
#  'punk': np.int64(2051),
#  'medium': np.int64(1645),
#  'percept': np.int64(1898),
#  'hole': np.int64(1248),
#  'pilot': np.int64(1928),
#  'team': np.int64(2646),
#  'blend': np.int64(263),
#  'chabrol': np.int64(388),
#  'master': np.int64(1624),
#  'innuendo': np.int64(1369),
#  'rivet': np.int64(2188),
#  'war': np.int64(2896),
#  ...}

# %%
# Calculate statistical similarity
sim_5_100_tfidf = cosine_similarity(train_tfidf_stem[4].toarray()[0],
                             train_tfidf_stem[99].toarray()[0])
sim_5_15000_tfidf = cosine_similarity(train_tfidf_stem[4].toarray()[0],
                               train_tfidf_stem[14999].toarray()[0])
sim_5_50000_tfidf = cosine_similarity(train_tfidf_stem[4].toarray()[0],
                               train_tfidf_stem[49999].toarray()[0])

# %%
print(f"{stem_train[4]} \n {sim_5_100_tfidf} \n {stem_train[99]}")
# Out:
# worst revengeofthenerd cliché filmmak could dredg
#  0.0
#  act direct clear washington certainli new career ahead

# %%
print(f"{stem_train[4]} \n {sim_5_15000_tfidf} \n {stem_train[14999]}")
# Out:
# worst revengeofthenerd cliché filmmak could dredg
#  0.0
#  eloqu

# %%
print(f"{stem_train[4]} \n {sim_5_50000_tfidf} \n {stem_train[49999]}")
# Out:
# worst revengeofthenerd cliché filmmak could dredg
#  0.0
#  stylish

# %% [markdown]
# ## ✅ 10. Logistic Regression
# using scikit-learn first with the Bag-of-Words and then TF-IDF, and report the performance of the sentiment classifier.

# %% [markdown]
# ### BoW

# %% [markdown]
# **lemmatised sentences**

# %%
# For BoW - lemmatised sentences:
clf_bow_lemma = LogisticRegression()
clf_bow_lemma.fit(train_bow_lemma, train_label)

train_score_bow_lemma = clf_bow_lemma.score(train_bow_lemma, train_label)

# %%
train_score_bow_lemma
# Out:
# 0.8421802847852232

# %%
# Evaluate the model
y_pred_bow_lemma = clf_bow_lemma.predict(val_bow_lemma)
print(classification_report(y_pred_bow_lemma, val_label))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.81      0.75       368
#            1       0.84      0.74      0.79       504
#
#     accuracy                           0.77       872
#    macro avg       0.77      0.78      0.77       872
# weighted avg       0.78      0.77      0.77       872

# %% [markdown]
# **stemmed sentences**

# %%
# For BoW - stemmed sentences:
clf_bow_stem = LogisticRegression()
clf_bow_stem.fit(train_bow_stem, train_label)

train_score_bow_stem = clf_bow_stem.score(train_bow_stem, train_label)

# %%
train_score_bow_stem
# Out:
# 0.8507475983310814

# %%
# Evaluate the model
y_pred_bow_stem = clf_bow_stem.predict(val_bow_stem)
print(classification_report(y_pred_bow_stem, val_label))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.82      0.76       363
#            1       0.86      0.75      0.80       509
#
#     accuracy                           0.78       872
#    macro avg       0.78      0.79      0.78       872
# weighted avg       0.79      0.78      0.78       872

# %% [markdown]
# ### TF-IDF

# %% [markdown]
# **lemmatised sentences**

# %%
# For TF-IDF - lemmatised sentences:
clf_tfidf_lemma = LogisticRegression()
clf_tfidf_lemma.fit(train_tfidf_lemma, train_label)

train_score_tfidf_lemma = clf_tfidf_lemma.score(train_tfidf_lemma, train_label)

# %%
train_score_tfidf_lemma
# Out:
# 0.8389582621865209

# %%
# Evaluate the model
y_pred_tfidf_lemma = clf_tfidf_lemma.predict(val_tfidf_lemma)
print(classification_report(y_pred_tfidf_lemma, val_label))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.84      0.76       357
#            1       0.87      0.75      0.81       515
#
#     accuracy                           0.79       872
#    macro avg       0.78      0.79      0.78       872
# weighted avg       0.80      0.79      0.79       872

# %% [markdown]
# **stemmed sentences**

# %%
# For TF-IDF - stemmed sentences:
clf_tfidf_stem = LogisticRegression()
clf_tfidf_stem.fit(train_tfidf_stem, train_label)

train_score_tfidf_stem = clf_tfidf_stem.score(train_tfidf_stem, train_label)

# %%
train_score_tfidf_stem
# Out:
# 0.8482085851311824

# %%
# Evaluate the model
y_pred_tfidf_stem = clf_tfidf_stem.predict(val_tfidf_stem)
print(classification_report(y_pred_tfidf_stem, val_label))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.84      0.76       359
#            1       0.87      0.75      0.80       513
#
#     accuracy                           0.79       872
#    macro avg       0.78      0.79      0.78       872
# weighted avg       0.80      0.79      0.79       872

# %% [markdown]
# **All models compared to each other**

# %%
print(f"BoW lemmatised sentences \n {classification_report(y_pred_bow_lemma, val_label)}")
print(f"BoW stemmed sentences \n {classification_report(y_pred_bow_stem, val_label)}")
print(f"TF-IDF lemmatised sentences \n {classification_report(y_pred_tfidf_lemma, val_label)}")
print(f"TF-IDF stemmed sentences \n {classification_report(y_pred_tfidf_stem, val_label)}")
# Out:
# BoW lemmatised sentences
#                precision    recall  f1-score   support
#
#            0       0.70      0.81      0.75       368
#            1       0.84      0.74      0.79       504
#
#     accuracy                           0.77       872
#    macro avg       0.77      0.78      0.77       872
# weighted avg       0.78      0.77      0.77       872
#
# BoW stemmed sentences
#                precision    recall  f1-score   support
#
#            0       0.70      0.82      0.76       363
#            1       0.86      0.75      0.80       509
#
#     accuracy                           0.78       872
#    macro avg       0.78      0.79      0.78       872
# weighted avg       0.79      0.78      0.78       872
#
# TF-IDF lemmatised sentences
#                precision    recall  f1-score   support
#
#            0       0.70      0.84      0.76       357
#            1       0.87      0.75      0.81       515
#
#     accuracy                           0.79       872
#    macro avg       0.78      0.79      0.78       872
# weighted avg       0.80      0.79      0.79       872
#
# TF-IDF stemmed sentences
#                precision    recall  f1-score   support
#
#            0       0.70      0.84      0.76       359
#            1       0.87      0.75      0.80       513
#
#     accuracy                           0.79       872
#    macro avg       0.78      0.79      0.78       872
# weighted avg       0.80      0.79      0.79       872

# %% [markdown]
# # 💠 Insights on Model Performance

# %% [markdown]
# # 💠 Insights on Similarity
#
# **GloVe**
#
# - Pre-trained word embeddings (300 dimensions)
# - Understands semantic meaning and word relationships
# - Each word is converted to a vector capturing its meaning
# - Sentences are averaged word vectors
#
# *Strengths:*
# - Captures semantic relationships
# - Recognises "good" and "great" as similar
# - Recognises "good" and "bad" as opposite
# - Produces non-zero similarities between random reviews
# - Understands context and meaning
# - Good for classification tasks
#
# *Weaknesses:*
# - Requires pre-trained model (must download)
# - Maps all instances of same word to same vector
# - May miss rare words not in training data
# - Slower than BoW and TF-IDF
#
# *Best For:*
# - Sentiment analysis
# - Semantic similarity
# - Text classification
# - Understanding meaning
# - Paraphrase detection
#
# *Not Good For:*
# - Exact duplicate detection
# - Spam filtering (need exact patterns)
# - Simple word counting tasks
#
#
#
# **Word2Vec** (Word to Vector)
#
# - Neural network model that learns word embeddings from your corpus
# - Trains on local word contexts (nearby words)
# - Each word converted to a vector (typically 100-300 dimensions)
# - Sentences are averaged word vectors
# - Two approaches: Skip-gram and CBOW
#
# *Strengths:*
# - Captures semantic relationships like GloVe
# - Trained on your specific corpus (learns domain-specific meanings)
# - "good" and "great" recognised as similar
# - "good" and "bad" recognised as opposite
# - Better than GloVe for domain-specific text
# - Produces non-zero similarities between random reviews
# - Can find most similar words to any word
#
# *Weaknesses:*
# - Requires training on your data (slow for large datasets)
# - Needs sufficient data to train well
# - Different training runs produce different vectors
# - Can overfit with small datasets
# - More complex to implement than TF-IDF or BoW
#
# *Best For:*
# - Sentiment analysis on domain-specific text
# - Semantic similarity in specialized domains
# - Text classification with custom embeddings
# - Understanding meaning in your specific corpus
# - When you have enough training data
#
# *Not Good For:*
# - Small datasets (won't train well)
# - Exact duplicate detection
# - Spam filtering (need exact patterns)
# - When you need pre-trained general knowledge
#
#
#
# **BoW**
#
# - Counts word occurrences in each document
# - Ignores word order and document structure
# - Creates sparse vectors (mostly zeros)
# - Each word equals its count
#
# *Strengths:*
# - Very simple and fast
# - Easy to implement
# - Good for exact word matching
# - Easy to interpret
# - Low computational cost
# - Works with small datasets
#
# *Weaknesses:*
# - No information about word importance
# - Only exact word overlap
# - Zero for random sentences with no common words
# - Loses word order completely
# - Treats "good" and "great" as different words
# - High sparsity (mostly zeros)
# - Treats all words equally
#
# *Best For:*
# - Duplicate detection (exact same words)
# - Spam filtering (similar document structure)
# - Topic matching (documents about exact same topic)
# - Simple baseline
# - Large-scale document retrieval
#
# *Not Good For:*
# - Sentiment analysis (different words for same sentiment)
# - Paraphrase detection (same meaning, different words)
# - General text similarity
# - Semantic tasks
# - Synonym handling
#
#
# **TF-IDF**
#
# - Weights words by their importance (frequency times rarity)
# - TF: how often a word appears in a document
# - IDF: how rare a word is across all documents
# - Each word gets a weight between 0 and 1
# - Sentences become weighted word vectors
#
# *Strengths:*
# - Simple and fast
# - Easy to understand and interpret
# - Emphasises distinctive and important words
# - Better than BoW for text classification
# - Handles variable-length documents well
# - Good baseline method
#
# *Weaknesses:*
# - Relies only on word overlap
# - Different words mean zero similarity
# - Produces zero for random sentences with no common words
# - Treats "good" and "great" as completely different
# - Cannot recognise synonyms
# - Creates high-dimensional sparse vectors
#
# *Best For:*
# - Text classification when words matter
# - Information retrieval
# - Baseline comparisons
# - Simple similarity tasks
# - Documents with repeated keywords
#
# *Not Good For:*
# - Sentiment analysis (needs semantic understanding)
# - Paraphrase detection (different words = 0)
# - General semantic similarity
# - Handling synonyms
#
#
# Considering all these nuances, it is normal that GloVe and Word2Vec give non-zero, BoW and TF-IDF give zero similarities. Brcause diverse reviews have different vocabulary.
#
# Word2Vec is trained on the specific corpus (movie reviews), therefore learns the specific patterns in our data.
# GloVe is pre-trained on billions of general words, so captures broader semantic meaning.
#
# **Word2Vec:**
#
# - Gives more moderate scores (clusters closer together)
# - Less able to distinguish between different meanings
# - Reason: Trained on limited corpus (just our data)
#
# **GloVe:**
#
# - Gives wider range of scores
# - Better at distinguishing similar vs dissimilar
# - More confident in judgments
# - Reason: Trained on massive general corpus
